# %%
import psycopg2 as pg
import networkx as nx
import pandas as pd
import pandas.io.sql as psql
import os
from tqdm.notebook import tqdm
from itertools import product
import pickle
import numpy as np

# %%
# connect to CODA DB
conn = pg.connect(host = 'heart5.kaist.ac.kr', dbname="CODAv3.0", user='bisler', password='bislaprom3')
cur = conn.cursor()

# %%
def create_network(coda_df):
  relation_df = coda_df[['leftentityid', 'rightentityid']]
  relation_df = relation_df.drop_duplicates()
  reverse_df = coda_df.loc[coda_df['association']=='Undirected_Link'][['rightentityid', 'leftentityid']]
  reverse_df = reverse_df.rename(columns={'rightentityid':'leftentityid', 'leftentityid':'rightentityid'})
  reverse_df = reverse_df.drop_duplicates()
  relation_df = pd.concat([relation_df, reverse_df])
  g = nx.from_pandas_edgelist(relation_df, 'leftentityid', 'rightentityid', create_using=nx.DiGraph())
  return g

def get_edge_list(coda_df):
  relation_df = coda_df[['leftentityid', 'rightentityid']]
  relation_df = relation_df.drop_duplicates()
  return relation_df

def execute_sql_to_df(conn, sql_query):
  return psql.read_sql(sql_query, conn)

# %%
def get_gene_name(entrezid):
    sql_query = "SELECT symbol FROM gene where entrezid = '{}'".format(entrezid)
    cur.execute(sql_query)
    try:
        symbol = cur.fetchone()[0]
        return symbol
    except:
        pass
    
def get_gene_id(symbol):
    sql_query = "SELECT entrezid FROM gene where symbol = '{}' and ncbitaxid = '9606'".format(symbol.upper())
    cur.execute(sql_query)
    try:
        entrezid = cur.fetchone()[0]
        return entrezid
    except:
        pass

def to_dictionary(entrezid_list):
    result = dict()
    for entrezid in tqdm(entrezid_list):
        symbol = get_gene_name(entrezid)
        if symbol is not None:
            symbol = symbol.upper()
            result[symbol] = entrezid
    return result
    
def symbol2GE(symbol_list):
    result = list()
    for symbol in symbol_list:
        try:
            sql_query = "SELECT geneid from gene where symbol = '{}' and ncbitaxid = '9606'".format(symbol.upper())
            cur = conn.cursor()
            cur.execute(sql_query)
            geid = cur.fetchone()[0]
            result.append(geid)
        except:
            print(symbol)
    return result

def GE2GP(ge_list):
    result = list()
    for ge in ge_list:
        sql_query = "select geneproductid from geneproduct where geneid = '{}'".format(ge)
        cur = conn.cursor()
        cur.execute(sql_query)
        gpids = cur.fetchall()
        gpids = [gpid[0] for gpid in gpids]
        result += gpids
    return result

def GP2symbol(gp_list):
    result = list()
    for gp in gp_list:
        sql_query = "select symbol from geneproduct where geneproductid = '{}'".format(gp)
        cur = conn.cursor()
        cur.execute(sql_query)
        symbol = cur.fetchone()[0]
        result.append(symbol)
    return result

def GP2symbol_single(gp):
    sql_query = "select symbol from geneproduct where geneproductid = '{}'".format(gp)
    cur = conn.cursor()
    cur.execute(sql_query)
    try:
        symbol = cur.fetchone()[0]
    except:
        symbol = None
    return symbol

def filter_gene_in_g(g, gene_list):
    return [gene for gene in gene_list if g.has_node(gene)]

# %%
# select non-context relations
sql_query = "SELECT * FROM knowledgeunit where leftorganid is Null and lefttissueid is Null and leftcellid is Null and rightorganid is Null and righttissueid is Null and rightcellid is Null and associationcontext is Null and lefttype='GP' and righttype='GP';"
non_context_df = execute_sql_to_df(conn, sql_query)

# %%
non_context_df
# Out:
#             kuid lefttype leftentityid leftorganid lefttissueid leftcellid  \
# 0              1       GP   GP00000001        None         None       None
# 1              5       GP   GP00000006        None         None       None
# 2              6       GP   GP00000008        None         None       None
# 3              8       GP   GP00000011        None         None       None
# 4             13       GP   GP00000013        None         None       None
# ...          ...      ...          ...         ...          ...        ...
# 618852  22187918       GP   GP00032393        None         None       None
# 618853  22187919       GP   GP00045273        None         None       None
# 618854  22187920       GP   GP00025526        None         None       None
# 618855  22187921       GP   GP00018717        None         None       None
# 618856  22187922       GP   GP00017710        None         None       None
#
#               association righttype rightentityid rightorganid righttissueid  \
# 0       Positive_Increase        GP    GP00000002         None          None
# 1       Positive_Increase        GP    GP00000007         None          None
# 2       Positive_Increase        GP    GP00000009         None          None
# 3       Positive_Increase        GP    GP00000012         None          None
# 4       Positive_Increase        GP    GP00000014         None          None
# ...                   ...       ...           ...          ...           ...
# 618852      Directed_Link        GP    GP00045144         None          None
# 618853      Directed_Link        GP    GP00067429         None          None
# 618854      Directed_Link        GP    GP00069215         None          None
# 618855      Directed_Link        GP    GP00074387         None          None
# 618856      Directed_Link        GP    GP00059779         None          None
#
#        rightcellid associationcontext associationinsource   speciesid  \
# 0             None               None                Bind  SP00000445
# 1             None               None                Bind  SP00000445
# 2             None               None                Bind  SP00000445
# 3             None               None                Bind  SP00000445
# 4             None               None                Bind  SP00000445
# ...            ...                ...                 ...         ...
# 618852        None               None            Regulate  SP00000445
# 618853        None               None            Regulate  SP00000445
# 618854        None               None            Regulate  SP00000445
# 618855        None               None            Regulate  SP00000445
# 618856        None               None            Regulate  SP00000445
#
#         referenceid             evidencescore level
# 0                 1  {'Manual_Curation': 1.0}     0
# 1                 5  {'Manual_Curation': 1.0}     0
# 2                 6  {'Manual_Curation': 1.0}     0
# 3                 8  {'Manual_Curation': 1.0}     0
# 4                 9  {'Manual_Curation': 1.0}     0
# ...             ...                       ...   ...
# 618852        69207  {'Manual_Curation': '1'}     0
# 618853        69207                      None     0
# 618854        69207  {'Manual_Curation': '1'}     0
# 618855        69207  {'Manual_Curation': '1'}     0
# 618856        69207  {'Manual_Curation': '1'}     0
#
# [618857 rows x 18 columns]

# %%
# create network
ppi_df = non_context_df[(non_context_df['lefttype']=='GP') & (non_context_df['righttype']=='GP')]

GP_list = list(set(ppi_df['leftentityid'].to_list())) + list(set(ppi_df['rightentityid'].to_list()))
GP_list = list(set(GP_list))

symbol_list = GP2symbol(GP_list)
zip_iterator = zip(GP_list, symbol_list)
gp_symbol_dict = dict(zip_iterator)

ppi_df['leftentityid'] = ppi_df['leftentityid'].apply(lambda x: get_gene_id(gp_symbol_dict[x]))
ppi_df['rightentityid'] = ppi_df['rightentityid'].apply(lambda x: get_gene_id(gp_symbol_dict[x]))
# Out:
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# ...
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol
# symbol

# %%
ppi_df
# Out:
#             kuid lefttype leftentityid leftorganid lefttissueid leftcellid  \
# 0              1       GP         5443        None         None       None
# 1              5       GP         3458        None         None       None
# 2              6       GP         3084        None         None       None
# 3              8       GP         3827        None         None       None
# 4             13       GP       282617        None         None       None
# ...          ...      ...          ...         ...          ...        ...
# 618852  22187918       GP         6689        None         None       None
# 618853  22187919       GP       406955        None         None       None
# 618854  22187920       GP         1961        None         None       None
# 618855  22187921       GP         6667        None         None       None
# 618856  22187922       GP          860        None         None       None
#
#               association righttype rightentityid rightorganid righttissueid  \
# 0       Positive_Increase        GP          4988         None          None
# 1       Positive_Increase        GP          3459         None          None
# 2       Positive_Increase        GP          2066         None          None
# 3       Positive_Increase        GP           623         None          None
# 4       Positive_Increase        GP          3588         None          None
# ...                   ...       ...           ...          ...           ...
# 618852      Directed_Link        GP          3684         None          None
# 618853      Directed_Link        GP         23411         None          None
# 618854      Directed_Link        GP          1749         None          None
# 618855      Directed_Link        GP          2264         None          None
# 618856      Directed_Link        GP          3381         None          None
#
#        rightcellid associationcontext associationinsource   speciesid  \
# 0             None               None                Bind  SP00000445
# 1             None               None                Bind  SP00000445
# 2             None               None                Bind  SP00000445
# 3             None               None                Bind  SP00000445
# 4             None               None                Bind  SP00000445
# ...            ...                ...                 ...         ...
# 618852        None               None            Regulate  SP00000445
# 618853        None               None            Regulate  SP00000445
# 618854        None               None            Regulate  SP00000445
# 618855        None               None            Regulate  SP00000445
# 618856        None               None            Regulate  SP00000445
#
#         referenceid             evidencescore level
# 0                 1  {'Manual_Curation': 1.0}     0
# 1                 5  {'Manual_Curation': 1.0}     0
# 2                 6  {'Manual_Curation': 1.0}     0
# 3                 8  {'Manual_Curation': 1.0}     0
# 4                 9  {'Manual_Curation': 1.0}     0
# ...             ...                       ...   ...
# 618852        69207  {'Manual_Curation': '1'}     0
# 618853        69207                      None     0
# 618854        69207  {'Manual_Curation': '1'}     0
# 618855        69207  {'Manual_Curation': '1'}     0
# 618856        69207  {'Manual_Curation': '1'}     0
#
# [618857 rows x 18 columns]

# %%
ppi_df.loc[(ppi_df['leftentityid'] == '1961') & (ppi_df['rightentityid'] == '1749')]
# Out:
#             kuid lefttype leftentityid leftorganid lefttissueid leftcellid  \
# 618854  22187920       GP         1961        None         None       None
#
#           association righttype rightentityid rightorganid righttissueid  \
# 618854  Directed_Link        GP          1749         None          None
#
#        rightcellid associationcontext associationinsource   speciesid  \
# 618854        None               None            Regulate  SP00000445
#
#         referenceid             evidencescore level
# 618854        69207  {'Manual_Curation': '1'}     0

# %%
none_df = non_context_df[non_context_df['kuid'].isin(list(ppi_df[TF]['kuid'].values))]

none_df['leftentityid'] = none_df['leftentityid'].apply(lambda x: gp_symbol_dict[x])
none_df['rightentityid'] = none_df['rightentityid'].apply(lambda x: gp_symbol_dict[x])
# Out:
# /tmp/ipykernel_45232/2488382304.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   none_df['leftentityid'] = none_df['leftentityid'].apply(lambda x: gp_symbol_dict[x])
# /tmp/ipykernel_45232/2488382304.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   none_df['rightentityid'] = none_df['rightentityid'].apply(lambda x: gp_symbol_dict[x])

# %%
none_df
# Out:
#            kuid lefttype    leftentityid leftorganid lefttissueid leftcellid  \
# 1842   10918331       GP  ProteinComplex        None         None       None
# 3665   10920336       GP  ProteinComplex        None         None       None
# 3666   10920337       GP  ProteinComplex        None         None       None
# 3936   10920624       GP  ProteinComplex        None         None       None
# 3939   10920627       GP  ProteinComplex        None         None       None
# ...         ...      ...             ...         ...          ...        ...
# 86624  11016831       GP  ProteinComplex        None         None       None
# 86674  11016885       GP  ProteinComplex        None         None       None
# 86675  11016886       GP  ProteinComplex        None         None       None
# 86676  11016887       GP  ProteinComplex        None         None       None
# 86677  11016888       GP  ProteinComplex        None         None       None
#
#              association righttype   rightentityid rightorganid righttissueid  \
# 1842   Positive_Increase        GP             FOS         None          None
# 3665   Positive_Increase        GP           RAP1B         None          None
# 3666   Positive_Increase        GP           RAP1A         None          None
# 3936   Positive_Increase        GP           CDC42         None          None
# 3939   Positive_Increase        GP            RAC1         None          None
# ...                  ...       ...             ...          ...           ...
# 86624  Positive_Increase        GP           ITGB3         None          None
# 86674  Positive_Increase        GP  ProteinComplex         None          None
# 86675  Positive_Increase        GP  ProteinComplex         None          None
# 86676  Positive_Increase        GP  ProteinComplex         None          None
# 86677  Positive_Increase        GP  ProteinComplex         None          None
#
#       rightcellid associationcontext         associationinsource   speciesid  \
# 1842         None               None                  Expression  SP00000445
# 3665         None               None                  Activation  SP00000445
# 3666         None               None                  Activation  SP00000445
# 3936         None               None                  Activation  SP00000445
# 3939         None               None                  Activation  SP00000445
# ...           ...                ...                         ...         ...
# 86624        None               None  Activation|Indirect_effect  SP00000445
# 86674        None               None                  Activation  SP00000445
# 86675        None               None                  Activation  SP00000445
# 86676        None               None                  Activation  SP00000445
# 86677        None               None                  Activation  SP00000445
#
#        referenceid             evidencescore level
# 1842         50211  {'Manual_Curation': 1.0}     0
# 3665         50372  {'Manual_Curation': 1.0}     0
# 3666         50372  {'Manual_Curation': 1.0}     0
# 3936         50372  {'Manual_Curation': 1.0}     0
# 3939         50372  {'Manual_Curation': 1.0}     0
# ...            ...                       ...   ...
# 86624        51829  {'Manual_Curation': 1.0}     0
# 86674        51829  {'Manual_Curation': 1.0}     0
# 86675        51829  {'Manual_Curation': 1.0}     0
# 86676        51829  {'Manual_Curation': 1.0}     0
# 86677        51829  {'Manual_Curation': 1.0}     0
#
# [15796 rows x 18 columns]

# %%
# Proteincomplex deletion
print("Length of none_df is " + str(len(none_df['kuid'])))

pc_num = 0

for kuid in none_df['kuid']:
    test_df = none_df[none_df['kuid']==kuid]
    test_df
    if test_df['leftentityid'].values == 'ProteinComplex' or test_df['rightentityid'].values == 'ProteinComplex':
        pc_num += 1
        
print("Total number of Protein Complex rows is " + str(pc_num))

if len(none_df['kuid']) == pc_num:
    print("\n All None is ProteinComplex")
# Out:
# Length of none_df is 15796
# Total number of Protein Complex rows is 15796
#
#  All None is ProteinComplex

# %% [raw]
# We need to delete "Protein Complex" in the dataframe

# %%
sum((ppi_df['leftentityid'].notna()) & (ppi_df['rightentityid'].notna()))
# Out:
# 578576

# %%
sum(ppi_df['leftentityid'].notna())
# Out:
# 603061

# %%
sum(ppi_df['leftentityid'].isna())
# Out:
# 15796

# %%
ppi_df_notna = ppi_df[(ppi_df['leftentityid'].notna()) & (ppi_df['rightentityid'].notna())] # ppi dataframe with no NaN

ppi_df_notna = ppi_df_notna.reset_index(drop=True) # index reset

ppi_df_notna
# Out:
#             kuid lefttype leftentityid leftorganid lefttissueid leftcellid  \
# 0              1       GP         5443        None         None       None
# 1              5       GP         3458        None         None       None
# 2              6       GP         3084        None         None       None
# 3              8       GP         3827        None         None       None
# 4             13       GP       282617        None         None       None
# ...          ...      ...          ...         ...          ...        ...
# 578571  22187918       GP         6689        None         None       None
# 578572  22187919       GP       406955        None         None       None
# 578573  22187920       GP         1961        None         None       None
# 578574  22187921       GP         6667        None         None       None
# 578575  22187922       GP          860        None         None       None
#
#               association righttype rightentityid rightorganid righttissueid  \
# 0       Positive_Increase        GP          4988         None          None
# 1       Positive_Increase        GP          3459         None          None
# 2       Positive_Increase        GP          2066         None          None
# 3       Positive_Increase        GP           623         None          None
# 4       Positive_Increase        GP          3588         None          None
# ...                   ...       ...           ...          ...           ...
# 578571      Directed_Link        GP          3684         None          None
# 578572      Directed_Link        GP         23411         None          None
# 578573      Directed_Link        GP          1749         None          None
# 578574      Directed_Link        GP          2264         None          None
# 578575      Directed_Link        GP          3381         None          None
#
#        rightcellid associationcontext associationinsource   speciesid  \
# 0             None               None                Bind  SP00000445
# 1             None               None                Bind  SP00000445
# 2             None               None                Bind  SP00000445
# 3             None               None                Bind  SP00000445
# 4             None               None                Bind  SP00000445
# ...            ...                ...                 ...         ...
# 578571        None               None            Regulate  SP00000445
# 578572        None               None            Regulate  SP00000445
# 578573        None               None            Regulate  SP00000445
# 578574        None               None            Regulate  SP00000445
# 578575        None               None            Regulate  SP00000445
#
#         referenceid             evidencescore level
# 0                 1  {'Manual_Curation': 1.0}     0
# 1                 5  {'Manual_Curation': 1.0}     0
# 2                 6  {'Manual_Curation': 1.0}     0
# 3                 8  {'Manual_Curation': 1.0}     0
# 4                 9  {'Manual_Curation': 1.0}     0
# ...             ...                       ...   ...
# 578571        69207  {'Manual_Curation': '1'}     0
# 578572        69207                      None     0
# 578573        69207  {'Manual_Curation': '1'}     0
# 578574        69207  {'Manual_Curation': '1'}     0
# 578575        69207  {'Manual_Curation': '1'}     0
#
# [578576 rows x 18 columns]

# %%
# PDC gene check

ppi_df_notna.loc[(ppi_df_notna['leftentityid'] == '5132') | (ppi_df_notna['rightentityid'] == '5132')]
# Out:
#             kuid lefttype leftentityid leftorganid lefttissueid leftcellid  \
# 165472  12269531       GP          156        None         None       None
# 211517  12315576       GP         5132        None         None       None
# 292828  16503360       GP         1406        None         None       None
# 297822  16508354       GP         1870        None         None       None
# 414894  16625426       GP         8092        None         None       None
#
#             association righttype rightentityid rightorganid righttissueid  \
# 165472  Undirected_Link        GP          5132         None          None
# 211517  Undirected_Link        GP          5705         None          None
# 292828    Directed_Link        GP          5132         None          None
# 297822    Directed_Link        GP          5132         None          None
# 414894    Directed_Link        GP          5132         None          None
#
#        rightcellid associationcontext associationinsource   speciesid  \
# 165472        None               None            Interact  SP00000445
# 211517        None               None            Interact  SP00000445
# 292828        None               None                None  SP00000445
# 297822        None               None                None  SP00000445
# 414894        None               None                None  SP00000445
#
#         referenceid               evidencescore level
# 165472        57206    {'Manual_Curation': 1.0}     0
# 211517        63758    {'Manual_Curation': 1.0}     0
# 292828        69007  {'Discrete_Level': 'High'}     0
# 297822        69013  {'Discrete_Level': 'High'}     0
# 414894        69012  {'Discrete_Level': 'High'}     0

# %%
import json

with open('kegg/ko00001.json', 'r') as f:
    json_data = json.load(f)

# %%
get_gene_id('pDc')
# Out:
# '5132'

# %%
first_list = json_data['children'] # metabolism # Carbohydrate metabolism # Glycolysis

total_gene = []

for i in range(len(first_list)):
    for j in range(len(first_list[i]['children'][j])):
        for k in range(len(first_list[i]['children'][j]['children'])):
            if 'children' in first_list[i]['children'][j]['children'][k]:
                for l in range(len(first_list[i]['children'][j]['children'][k]['children'])):
                    #print(first_list[i]['children'][j]['children'][k]['children'][l])
                    ref = first_list[i]['children'][j]['children'][k]['children'][l]['name']
                    print(ref)
                    #ref2 = ref.split('  ')
                    #ref3 = ref2[1].split(';')
                    #total_gene.append(ref3[0])
# Out:
# K00844  HK; hexokinase [EC:2.7.1.1]
# K12407  GCK; glucokinase [EC:2.7.1.2]
# K00845  glk; glucokinase [EC:2.7.1.2]
# K25026  glk; glucokinase [EC:2.7.1.2]
# K01810  GPI, pgi; glucose-6-phosphate isomerase [EC:5.3.1.9]
# K06859  pgi1; glucose-6-phosphate isomerase, archaeal [EC:5.3.1.9]
# K13810  tal-pgi; transaldolase / glucose-6-phosphate isomerase [EC:2.2.1.2 5.3.1.9]
# K15916  pgi-pmi; glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]
# K24182  PFK9; 6-phosphofructokinase [EC:2.7.1.11]
# K00850  pfkA, PFK; 6-phosphofructokinase 1 [EC:2.7.1.11]
# K16370  pfkB; 6-phosphofructokinase 2 [EC:2.7.1.11]
# K21071  pfk, pfp; ATP-dependent phosphofructokinase / diphosphate-dependent phosphofructokinase [EC:2.7.1.11 2.7.1.90]
# K00918  pfkC; ADP-dependent phosphofructokinase/glucokinase [EC:2.7.1.146 2.7.1.147]
# K00895  pfp, PFP; diphosphate-dependent phosphofructokinase [EC:2.7.1.90]
# K03841  FBP, fbp; fructose-1,6-bisphosphatase I [EC:3.1.3.11]
# K02446  glpX; fructose-1,6-bisphosphatase II [EC:3.1.3.11]
# K11532  glpX-SEBP; fructose-1,6-bisphosphatase II / sedoheptulose-1,7-bisphosphatase [EC:3.1.3.11 3.1.3.37]
# K01086  fbp-SEBP; fructose-1,6-bisphosphatase I / sedoheptulose-1,7-bisphosphatase [EC:3.1.3.11 3.1.3.37]
# K04041  fbp3; fructose-1,6-bisphosphatase III [EC:3.1.3.11]
# K01623  ALDO; fructose-bisphosphate aldolase, class I [EC:4.1.2.13]
# K11645  fbaB; fructose-bisphosphate aldolase, class I [EC:4.1.2.13]
# K01624  FBA, fbaA; fructose-bisphosphate aldolase, class II [EC:4.1.2.13]
# K01622  K01622; fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]
# K16305  K16305; fructose-bisphosphate aldolase / 6-deoxy-5-ketofructose 1-phosphate synthase [EC:4.1.2.13 2.2.1.11]
# K16306  K16306; fructose-bisphosphate aldolase / 2-amino-3,7-dideoxy-D-threo-hept-6-ulosonate synthase [EC:4.1.2.13 2.2.1.10]
# K01803  TPI, tpiA; triosephosphate isomerase (TIM) [EC:5.3.1.1]
# K00134  GAPDH, gapA; glyceraldehyde 3-phosphate dehydrogenase (phosphorylating) [EC:1.2.1.12]
# K10705  GAPDHS; glyceraldehyde-3-phosphate dehydrogenase (phosphorylating), spermatogenic [EC:1.2.1.12]
# K00150  gap2; glyceraldehyde-3-phosphate dehydrogenase (NAD(P)) [EC:1.2.1.59]
# K00927  PGK, pgk; phosphoglycerate kinase [EC:2.7.2.3]
# K01834  PGAM, gpmA; 2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]
# K15634  gpmB; 2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]
# K15633  gpmI; 2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12]
# K15635  apgM; 2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12]
# K01689  ENO, eno; enolase [EC:4.2.1.11]
# K00873  PK, pyk; pyruvate kinase [EC:2.7.1.40]
# K12406  PKLR; pyruvate kinase isozymes R/L [EC:2.7.1.40]
# K01006  ppdK; pyruvate, orthophosphate dikinase [EC:2.7.9.1]
# K01007  pps, ppsA; pyruvate, water dikinase [EC:2.7.9.2]
# K00163  aceE; pyruvate dehydrogenase E1 component [EC:1.2.4.1]
# K00161  PDHA, pdhA; pyruvate dehydrogenase E1 component alpha subunit [EC:1.2.4.1]
# K00162  PDHB, pdhB; pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]
# K00627  DLAT, aceF, pdhC; pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]
# K00382  DLD, lpd, pdhD; dihydrolipoamide dehydrogenase [EC:1.8.1.4]
# K13997  PDHX; dihydrolipoamide dehydrogenase-binding protein of pyruvate dehydrogenase complex
# K00169  porA; pyruvate ferredoxin oxidoreductase alpha subunit [EC:1.2.7.1]
# K00170  porB; pyruvate ferredoxin oxidoreductase beta subunit [EC:1.2.7.1]
# K00172  porC, porG; pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.1]
# K00189  vorG, porG; 2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1]
# K00171  porD; pyruvate ferredoxin oxidoreductase delta subunit [EC:1.2.7.1]
# K03737  por, nifJ; pyruvate-ferredoxin/flavodoxin oxidoreductase [EC:1.2.7.1 1.2.7.-]
# K00174  korA, oorA, oforA; 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit alpha [EC:1.2.7.3 1.2.7.11]
# K00175  korB, oorB, oforB; 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit beta [EC:1.2.7.3 1.2.7.11]
# K00016  LDH, ldh; L-lactate dehydrogenase [EC:1.1.1.27]
# K01568  PDC, pdc; pyruvate decarboxylase [EC:4.1.1.1]
# K13951  ADH1_7; alcohol dehydrogenase 1/7 [EC:1.1.1.1]
# K13980  ADH4; alcohol dehydrogenase 4 [EC:1.1.1.1]
# K00121  frmA, ADH5, adhC; S-(hydroxymethyl)glutathione dehydrogenase / alcohol dehydrogenase [EC:1.1.1.284 1.1.1.1]
# K13952  ADH6; alcohol dehydrogenase 6 [EC:1.1.1.1]
# K04072  adhE; acetaldehyde dehydrogenase / alcohol dehydrogenase [EC:1.2.1.10 1.1.1.1]
# K13953  adhP; alcohol dehydrogenase, propanol-preferring [EC:1.1.1.1]
# K13954  yiaY; alcohol dehydrogenase [EC:1.1.1.1]
# K18857  ADH1; alcohol dehydrogenase class-P [EC:1.1.1.1]
# K00001  E1.1.1.1, adh; alcohol dehydrogenase [EC:1.1.1.1]
# K00002  AKR1A1, adh; alcohol dehydrogenase (NADP+) [EC:1.1.1.2]
# K12957  ahr; alcohol/geraniol dehydrogenase (NADP+) [EC:1.1.1.2 1.1.1.183]
# K13979  yahK; alcohol dehydrogenase (NADP+) [EC:1.1.1.2]
# K14028  mdh1, mxaF; methanol dehydrogenase (cytochrome c) subunit 1 [EC:1.1.2.7]
# K14029  mdh2, mxaI; methanol dehydrogenase (cytochrome c) subunit 2 [EC:1.1.2.7]
# K00114  exaA; alcohol dehydrogenase (cytochrome c) [EC:1.1.2.8]
# K04022  eutG; alcohol dehydrogenase
# K22473  adhA; alcohol dehydrogenase (quinone), dehydrogenase subunit [EC:1.1.5.5]
# K22474  adhB; alcohol dehydrogenase (quinone), cytochrome c subunit [EC:1.1.5.5]
# K00128  ALDH; aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]
# K14085  ALDH7A1; aldehyde dehydrogenase family 7 member A1 [EC:1.2.1.31 1.2.1.8 1.2.1.3]
# K00149  ALDH9A1; aldehyde dehydrogenase family 9 member A1 [EC:1.2.1.47 1.2.1.3]
# K00129  ALDH3; aldehyde dehydrogenase (NAD(P)+) [EC:1.2.1.5]
# K00138  aldB; aldehyde dehydrogenase [EC:1.2.1.-]
# K01895  ACSS1_2, acs; acetyl-CoA synthetase [EC:6.2.1.1]
# K01913  AAE7, ACN1; acetate/butyrate---CoA ligase [EC:6.2.1.1 6.2.1.2]
# K01905  acdA; acetate---CoA ligase (ADP-forming) subunit alpha [EC:6.2.1.13]
# K22224  acdB; acetate---CoA ligase (ADP-forming) subunit beta [EC:6.2.1.13]
# K24012  acdAB; acetate---CoA ligase (ADP-forming) [EC:6.2.1.13]
# K01785  galM, GALM; aldose 1-epimerase [EC:5.1.3.3]
# K01085  agp; glucose-1-phosphatase [EC:3.1.3.10]
# K20866  yihX; glucose-1-phosphatase [EC:3.1.3.10]
# K01835  pgm; phosphoglucomutase [EC:5.4.2.2]
# K15778  pmm-pgm; phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2]
# K15779  PGM2; phosphoglucomutase / phosphopentomutase [EC:5.4.2.2 5.4.2.7]
# K01084  G6PC; glucose-6-phosphatase [EC:3.1.3.9]
# K00886  ppgK; polyphosphate glucokinase [EC:2.7.1.63]
# K08074  ADPGK; ADP-dependent glucokinase [EC:2.7.1.147]
# K01792  E5.1.3.15; glucose-6-phosphate 1-epimerase [EC:5.1.3.15]
# K01837  BPGM; bisphosphoglycerate/phosphoglycerate mutase [EC:5.4.2.4 5.4.2.11]
# K03103  MINPP1; multiple inositol-polyphosphate phosphatase / 2,3-bisphosphoglycerate 3-phosphatase [EC:3.1.3.62 3.1.3.80]
# K11389  gapor; glyceraldehyde-3-phosphate dehydrogenase (ferredoxin) [EC:1.2.7.6]
# K00131  gapN; glyceraldehyde-3-phosphate dehydrogenase (NADP+) [EC:1.2.1.9]
# K18978  gapN; glyceraldehyde-3-phosphate dehydrogenase [NAD(P)+] [EC:1.2.1.90]
# K01596  E4.1.1.32, pckA, PCK; phosphoenolpyruvate carboxykinase (GTP) [EC:4.1.1.32]
# K01610  E4.1.1.49, pckA; phosphoenolpyruvate carboxykinase (ATP) [EC:4.1.1.49]
# K01222  E3.2.1.86A, celF; 6-phospho-beta-glucosidase [EC:3.2.1.86]
# K01223  E3.2.1.86B, bglA; 6-phospho-beta-glucosidase [EC:3.2.1.86]
# K02777  crr; sugar PTS system EIIA component [EC:2.7.1.-]
# K02779  ptsG; glucose PTS system EIICB or EIICBA component [EC:2.7.1.199]
# K02791  malX; maltose/glucose PTS system EIICB component [EC:2.7.1.199 2.7.1.208]
# K20118  ptsG, glcA, glcB; glucose PTS system EIICBA or EIICB component [EC:2.7.1.199]
# K02753  ascF; beta-glucoside (arbutin/salicin/cellobiose) PTS system EIICB component [EC:2.7.1.-]
# K01647  CS, gltA; citrate synthase [EC:2.3.3.1]
# K01648  ACLY; ATP citrate (pro-S)-lyase [EC:2.3.3.8]
# K15230  aclA; ATP-citrate lyase alpha-subunit [EC:2.3.3.8]
# K15231  aclB; ATP-citrate lyase beta-subunit [EC:2.3.3.8]
# K05942  E2.3.3.3; citrate (Re)-synthase [EC:2.3.3.3]
# K01681  ACO, acnA; aconitate hydratase [EC:4.2.1.3]
# K01682  acnB; aconitate hydratase 2 / 2-methylisocitrate dehydratase [EC:4.2.1.3 4.2.1.99]
# K00031  IDH1, IDH2, icd; isocitrate dehydrogenase [EC:1.1.1.42]
# K00030  IDH3; isocitrate dehydrogenase (NAD+) [EC:1.1.1.41]
# K17753  HICDH; isocitrate--homoisocitrate dehydrogenase [EC:1.1.1.286]
# K00164  OGDH, sucA; 2-oxoglutarate dehydrogenase E1 component [EC:1.2.4.2]
# K00658  DLST, sucB; 2-oxoglutarate dehydrogenase E2 component (dihydrolipoamide succinyltransferase) [EC:2.3.1.61]
# K01616  kgd; multifunctional 2-oxoglutarate metabolism enzyme [EC:2.2.1.5 4.1.1.71 1.2.4.2 2.3.1.61]
# K00382  DLD, lpd, pdhD; dihydrolipoamide dehydrogenase [EC:1.8.1.4]
# K00174  korA, oorA, oforA; 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit alpha [EC:1.2.7.3 1.2.7.11]
# K00175  korB, oorB, oforB; 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit beta [EC:1.2.7.3 1.2.7.11]
# K00177  korC, oorC; 2-oxoglutarate ferredoxin oxidoreductase subunit gamma [EC:1.2.7.3]
# K00176  korD, oorD; 2-oxoglutarate ferredoxin oxidoreductase subunit delta [EC:1.2.7.3]
# K01902  sucD; succinyl-CoA synthetase alpha subunit [EC:6.2.1.5]
# K01903  sucC; succinyl-CoA synthetase beta subunit [EC:6.2.1.5]
# K01899  LSC1; succinyl-CoA synthetase alpha subunit [EC:6.2.1.4 6.2.1.5]
# K01900  LSC2; succinyl-CoA synthetase beta subunit [EC:6.2.1.4 6.2.1.5]
# K18118  aarC, cat1; succinyl-CoA:acetate CoA-transferase [EC:2.8.3.18]
# K00234  SDHA, SDH1; succinate dehydrogenase (ubiquinone) flavoprotein subunit [EC:1.3.5.1]
# K00235  SDHB, SDH2; succinate dehydrogenase (ubiquinone) iron-sulfur subunit [EC:1.3.5.1]
# K00236  SDHC, SDH3; succinate dehydrogenase (ubiquinone) cytochrome b560 subunit
# K00237  SDHD, SDH4; succinate dehydrogenase (ubiquinone) membrane anchor subunit
# K25801  SDH4; succinate dehydrogenase (ubiquinone) subunit 4
# K00239  sdhA, frdA; succinate dehydrogenase / fumarate reductase, flavoprotein subunit [EC:1.3.5.1 1.3.5.4]
# K00240  sdhB, frdB; succinate dehydrogenase / fumarate reductase, iron-sulfur subunit [EC:1.3.5.1 1.3.5.4]
# K00241  sdhC, frdC; succinate dehydrogenase / fumarate reductase, cytochrome b subunit
# K00242  sdhD, frdD; succinate dehydrogenase / fumarate reductase, membrane anchor subunit
# K18859  sdhD, frdD; succinate dehydrogenase / fumarate reductase, subunit D
# K18860  sdhD, frdD; putative succinate dehydrogenase / fumarate reductase, subunit D
# K00244  frdA; fumarate reductase flavoprotein subunit [EC:1.3.5.4]
# K00245  frdB; fumarate reductase iron-sulfur subunit [EC:1.3.5.4]
# K00246  frdC; fumarate reductase subunit C
# K00247  frdD; fumarate reductase subunit D
# K01676  E4.2.1.2A, fumA, fumB; fumarate hydratase, class I [EC:4.2.1.2]
# K01677  E4.2.1.2AA, fumA; fumarate hydratase subunit alpha [EC:4.2.1.2]
# K01678  E4.2.1.2AB, fumB; fumarate hydratase subunit beta [EC:4.2.1.2]
# K01679  E4.2.1.2B, fumC, FH; fumarate hydratase, class II [EC:4.2.1.2]
# K01675  fumD; fumarate hydratase D [EC:4.2.1.2]
# K01774  fumE; fumarate hydratase E [EC:4.2.1.2]
# K00025  MDH1; malate dehydrogenase [EC:1.1.1.37]
# K00026  MDH2; malate dehydrogenase [EC:1.1.1.37]
# K00024  mdh; malate dehydrogenase [EC:1.1.1.37]
# K00116  mqo; malate dehydrogenase (quinone) [EC:1.1.5.4]
# K01958  PC, pyc; pyruvate carboxylase [EC:6.4.1.1]
# K01959  pycA; pyruvate carboxylase subunit A [EC:6.4.1.1]
# K01960  pycB; pyruvate carboxylase subunit B [EC:6.4.1.1]
# K01610  E4.1.1.49, pckA; phosphoenolpyruvate carboxykinase (ATP) [EC:4.1.1.49]
# K01596  E4.1.1.32, pckA, PCK; phosphoenolpyruvate carboxykinase (GTP) [EC:4.1.1.32]
# K00163  aceE; pyruvate dehydrogenase E1 component [EC:1.2.4.1]
# K00161  PDHA, pdhA; pyruvate dehydrogenase E1 component alpha subunit [EC:1.2.4.1]
# K00162  PDHB, pdhB; pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]
# K00627  DLAT, aceF, pdhC; pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]
# K13997  PDHX; dihydrolipoamide dehydrogenase-binding protein of pyruvate dehydrogenase complex
# K00169  porA; pyruvate ferredoxin oxidoreductase alpha subunit [EC:1.2.7.1]
# K00170  porB; pyruvate ferredoxin oxidoreductase beta subunit [EC:1.2.7.1]
# K00172  porC, porG; pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.1]
# K00189  vorG, porG; 2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1]
# K00171  porD; pyruvate ferredoxin oxidoreductase delta subunit [EC:1.2.7.1]
# K03737  por, nifJ; pyruvate-ferredoxin/flavodoxin oxidoreductase [EC:1.2.7.1 1.2.7.-]
# K01810  GPI, pgi; glucose-6-phosphate isomerase [EC:5.3.1.9]
# K06859  pgi1; glucose-6-phosphate isomerase, archaeal [EC:5.3.1.9]
# K13810  tal-pgi; transaldolase / glucose-6-phosphate isomerase [EC:2.2.1.2 5.3.1.9]
# K15916  pgi-pmi; glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]
# K00036  G6PD, zwf; glucose-6-phosphate 1-dehydrogenase [EC:1.1.1.49 1.1.1.363]
# K19243  azf; NAD+ dependent glucose-6-phosphate dehydrogenase [EC:1.1.1.388]
# K01057  PGLS, pgl, devB; 6-phosphogluconolactonase [EC:3.1.1.31]
# K07404  pgl; 6-phosphogluconolactonase [EC:3.1.1.31]
# K13937  H6PD; hexose-6-phosphate dehydrogenase [EC:1.1.1.47 3.1.1.31]
# K00033  PGD, gnd, gntZ; 6-phosphogluconate dehydrogenase [EC:1.1.1.44 1.1.1.343]
# K01783  rpe, RPE; ribulose-phosphate 3-epimerase [EC:5.1.3.1]
# K00615  E2.2.1.1, tktA, tktB; transketolase [EC:2.2.1.1]
# K00616  E2.2.1.2, talA, talB; transaldolase [EC:2.2.1.2]
# K01807  rpiA; ribose 5-phosphate isomerase A [EC:5.3.1.6]
# K01808  rpiB; ribose 5-phosphate isomerase B [EC:5.3.1.6]
# K13812  fae-hps; bifunctional enzyme Fae/Hps [EC:4.2.1.147 4.1.2.43]
# K08093  hxlA; 3-hexulose-6-phosphate synthase [EC:4.1.2.43]
# K08094  hxlB; 6-phospho-3-hexuloisomerase [EC:5.3.1.27]
# K13831  hps-phi; 3-hexulose-6-phosphate synthase / 6-phospho-3-hexuloisomerase [EC:4.1.2.43 5.3.1.27]
# K01621  xfp, xpk; xylulose-5-phosphate/fructose-6-phosphate phosphoketolase [EC:4.1.2.9 4.1.2.22]
# K01619  deoC, DERA; deoxyribose-phosphate aldolase [EC:4.1.2.4]
# K00852  rbsK, RBKS; ribokinase [EC:2.7.1.15]
# K01839  deoB; phosphopentomutase [EC:5.4.2.7]
# K22199  ppm; phosphopentomutase [EC:5.4.2.7]
# K01835  pgm; phosphoglucomutase [EC:5.4.2.2]
# K15778  pmm-pgm; phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2]
# K15779  PGM2; phosphoglucomutase / phosphopentomutase [EC:5.4.2.2 5.4.2.7]
# K05774  phnN; ribose 1,5-bisphosphokinase [EC:2.7.4.23]
# K00948  PRPS, prsA; ribose-phosphate pyrophosphokinase [EC:2.7.6.1]
# K01690  edd; phosphogluconate dehydratase [EC:4.2.1.12]
# K01625  eda; 2-dehydro-3-deoxyphosphogluconate aldolase / (4S)-4-hydroxy-2-oxoglutarate aldolase [EC:4.1.2.14 4.1.3.42]
# K17463  dgaF; 2-dehydro-3-deoxy-phosphogluconate aldolase [EC:4.1.2.14]
# K11395  kdpgA; 2-dehydro-3-deoxy-phosphogluconate/2-dehydro-3-deoxy-6-phosphogalactonate aldolase [EC:4.1.2.55]
# K00131  gapN; glyceraldehyde-3-phosphate dehydrogenase (NADP+) [EC:1.2.1.9]
# K18978  gapN; glyceraldehyde-3-phosphate dehydrogenase [NAD(P)+] [EC:1.2.1.90]
# K00034  gdh; glucose 1-dehydrogenase [EC:1.1.1.47]
# K22969  gdh; glucose 1-dehydrogenase [EC:1.1.1.47]
# K21840  HOX; hexose oxidase [EC:1.1.3.5]
# K18124  gdh2, gdhA; glucose/galactose 1-dehydrogenase (NADP+) [EC:1.1.1.360]
# K18125  ssgdh; aldose 1-dehydrogenase [NAD(P)+] [EC:1.1.1.359]
# K00115  GLD; glucose 1-dehydrogenase (FAD, quinone) [EC:1.1.5.9]
# K19813  gdh; glucose dehydrogenase [EC:1.1.5.9]
# K00117  gcd; quinoprotein glucose dehydrogenase [EC:1.1.5.2]
# K01053  gnl, RGN; gluconolactonase [EC:3.1.1.17]
# K06151  E1.1.99.3A; gluconate 2-dehydrogenase alpha chain [EC:1.1.99.3]
# K06152  E1.1.99.3G; gluconate 2-dehydrogenase gamma chain [EC:1.1.99.3]
# K00090  ghrB; glyoxylate/hydroxypyruvate/2-ketogluconate reductase [EC:1.1.1.79 1.1.1.81 1.1.1.215]
# K22229  K22229; 2-ketogluconate reductase [EC:1.1.1.215]
# K11441  kguK; dehydrogluconokinase [EC:2.7.1.13]
# K00032  E1.1.1.43; phosphogluconate 2-dehydrogenase [EC:1.1.1.43]
# K00851  idnK, gntK; gluconokinase [EC:2.7.1.12]
# K25031  gntK; gluconokinase [EC:2.7.1.12]
# K05308  gnaD; gluconate/galactonate dehydratase [EC:4.2.1.140]
# K00874  kdgK; 2-dehydro-3-deoxygluconokinase [EC:2.7.1.45]
# K18126  sskdgK; 2-dehydro-3-deoxygluconokinase / 2-dehydro-3-deoxygalactonokinase [EC:2.7.1.178]
# K18127  kdgA; 2-dehydro-3-deoxy-D-gluconate aldolase [EC:4.1.2.51]
# K03738  aor; aldehyde:ferredoxin oxidoreductase [EC:1.2.7.5]
# K18020  cutA; glyceraldehyde dehydrogenase large subunit [EC:1.2.99.8]
# K18021  cutB; glyceraldehyde dehydrogenase medium subunit [EC:1.2.99.8]
# K18022  cutC; glyceraldehyde dehydrogenase small subunit [EC:1.2.99.8]
# K18128  gadh; D-glyceraldehyde dehydrogenase (NADP+) [EC:1.2.1.89]
# K11529  gck, gckA, GLYCTK; glycerate 2-kinase [EC:2.7.1.165]
# K22345  E4.3.1.9; glucosaminate ammonia-lyase [EC:4.3.1.9]
# K17464  dgaA; D-glucosaminate PTS system EIIA component [EC:2.7.1.203]
# K17465  dgaB; D-glucosaminate PTS system EIIB component [EC:2.7.1.203]
# K17466  dgaC; D-glucosaminate PTS system EIIC component
# K17467  dgaD; D-glucosaminate PTS system EIID component
# K17468  dgaE; D-glucosaminate-6-phosphate ammonia-lyase [EC:4.3.1.29]
# K01623  ALDO; fructose-bisphosphate aldolase, class I [EC:4.1.2.13]
# K11645  fbaB; fructose-bisphosphate aldolase, class I [EC:4.1.2.13]
# K01624  FBA, fbaA; fructose-bisphosphate aldolase, class II [EC:4.1.2.13]
# K01622  K01622; fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]
# K16305  K16305; fructose-bisphosphate aldolase / 6-deoxy-5-ketofructose 1-phosphate synthase [EC:4.1.2.13 2.2.1.11]
# K16306  K16306; fructose-bisphosphate aldolase / 2-amino-3,7-dideoxy-D-threo-hept-6-ulosonate synthase [EC:4.1.2.13 2.2.1.10]
# K03841  FBP, fbp; fructose-1,6-bisphosphatase I [EC:3.1.3.11]
# K02446  glpX; fructose-1,6-bisphosphatase II [EC:3.1.3.11]
# K11532  glpX-SEBP; fructose-1,6-bisphosphatase II / sedoheptulose-1,7-bisphosphatase [EC:3.1.3.11 3.1.3.37]
# K01086  fbp-SEBP; fructose-1,6-bisphosphatase I / sedoheptulose-1,7-bisphosphatase [EC:3.1.3.11 3.1.3.37]
# K04041  fbp3; fructose-1,6-bisphosphatase III [EC:3.1.3.11]
# K24182  PFK9; 6-phosphofructokinase [EC:2.7.1.11]
# K00850  pfkA, PFK; 6-phosphofructokinase 1 [EC:2.7.1.11]
# K16370  pfkB; 6-phosphofructokinase 2 [EC:2.7.1.11]
# K21071  pfk, pfp; ATP-dependent phosphofructokinase / diphosphate-dependent phosphofructokinase [EC:2.7.1.11 2.7.1.90]
# K00918  pfkC; ADP-dependent phosphofructokinase/glucokinase [EC:2.7.1.146 2.7.1.147]
# K00895  pfp, PFP; diphosphate-dependent phosphofructokinase [EC:2.7.1.90]
# K01051  E3.1.1.11; pectinesterase [EC:3.1.1.11]
# K22539  PLY; pectate lyase [EC:4.2.2.2]
# K01728  pel; pectate lyase [EC:4.2.2.2]
# K19551  pelC; pectate lyase C [EC:4.2.2.2 4.2.2.10]
# K01731  pelW; pectate disaccharide-lyase [EC:4.2.2.9]
# K22994  pelX; pectate disaccharide-lyase [EC:4.2.2.9]
# K01730  ogl; oligogalacturonide lyase [EC:4.2.2.6]
# K01815  kduI; 4-deoxy-L-threo-5-hexosulose-uronate ketol-isomerase [EC:5.3.1.17]
# K00065  kduD; 2-dehydro-3-deoxy-D-gluconate 5-dehydrogenase [EC:1.1.1.127]
# K01184  E3.2.1.15; polygalacturonase [EC:3.2.1.15]
# K01213  E3.2.1.67; galacturan 1,4-alpha-galacturonidase [EC:3.2.1.67]
# K22933  lplD; galacturan 1,4-alpha-galacturonidase [EC:3.2.1.67]
# K01812  uxaC; glucuronate isomerase [EC:5.3.1.12]
# K00041  uxaB; tagaturonate reductase [EC:1.1.1.58]
# K01685  uxaA; altronate hydrolase [EC:4.2.1.7]
# K16849  uxaA1; altronate dehydratase small subunit [EC:4.2.1.7]
# K16850  uxaA2; altronate dehydratase large subunit [EC:4.2.1.7]
# K01686  uxuA; mannonate dehydratase [EC:4.2.1.8]
# K08323  rspA, manD; mannonate dehydratase [EC:4.2.1.8]
# K08322  rspB; L-gulonate 5-dehydrogenase [EC:1.1.1.380]
# K00040  uxuB; fructuronate reductase [EC:1.1.1.57]
# K21619  uxaE; tagaturonate epimerase [EC:5.1.2.7]
# K18106  GAAA; D-galacturonate reductase [EC:1.1.1.-]
# K19634  gar1; D-galacturonate reductase [EC:1.1.1.365]
# K18102  GAAB, LGD1; L-galactonate dehydratase [EC:4.2.1.146]
# K18103  GAAC, LGA1; L-threo-3-deoxy-hexylosonate aldolase [EC:4.1.2.54]
# K18107  GAAD; L-glyceraldehyde reductase [EC:1.1.1.372]
# K01195  uidA, GUSB; beta-glucuronidase [EC:3.2.1.31]
# K14756  KL; klotho [EC:3.2.1.31]
# K00699  UGT; glucuronosyltransferase [EC:2.4.1.17]
# K16190  GLCAK; glucuronokinase [EC:2.7.1.43]
# K12447  USP; UDP-sugar pyrophosphorylase [EC:2.7.7.64]
# K00012  UGDH, ugd; UDPglucose 6-dehydrogenase [EC:1.1.1.22]
# K00963  UGP2, galU, galF; UTP--glucose-1-phosphate uridylyltransferase [EC:2.7.7.9]
# K00002  AKR1A1, adh; alcohol dehydrogenase (NADP+) [EC:1.1.1.2]
# K13247  CRYL1; L-gulonate 3-dehydrogenase [EC:1.1.1.45]
# K08092  dlgD; 3-dehydro-L-gulonate 2-dehydrogenase [EC:1.1.1.130]
# K00880  lyxK; L-xylulokinase [EC:2.7.1.53]
# K03078  ulaD, sgaH, sgbH; 3-dehydro-L-gulonate-6-phosphate decarboxylase [EC:4.1.1.85]
# K03079  ulaE, sgaU, sgbU; L-ribulose-5-phosphate 3-epimerase [EC:5.1.3.22]
# K03077  araD, ulaF, sgaE, sgbE; L-ribulose-5-phosphate 4-epimerase [EC:5.1.3.4]
# K01783  rpe, RPE; ribulose-phosphate 3-epimerase [EC:5.1.3.1]
# K01804  araA; L-arabinose isomerase [EC:5.3.1.4]
# K00853  araB; L-ribulokinase [EC:2.7.1.16]
# K24707  E2.7.1.16; ribulokinase [EC:2.7.1.16]
# K00854  xylB, XYLB; xylulokinase [EC:2.7.1.17]
# K01805  xylA; xylose isomerase [EC:5.3.1.5]
# K00011  AKR1B; aldehyde reductase [EC:1.1.1.21]
# K00594  xyoA, aldO; alditol oxidase [EC:1.1.3.41]
# K17743  XR; D-xylose reductase [EC:1.1.1.307]
# K03331  DCXR; L-xylulose reductase [EC:1.1.1.10]
# K25879  LXRA; L-xylulose reductase [EC:1.1.1.10]
# K25880  LADA; L-arabinitol 4-dehydrogenase [EC:1.1.1.12]
# K25881  LARA; L-arabinose reductase [EC:1.1.1.-]
# K01820  rhaA; L-rhamnose isomerase / sugar isomerase [EC:5.3.1.14 5.3.1.-]
# K00848  rhaB; rhamnulokinase [EC:2.7.1.5]
# K01629  rhaD; rhamnulose-1-phosphate aldolase [EC:4.1.2.19]
# K17738  ARD; D-arabinitol 2-dehydrogenase [EC:1.1.1.250]
# K17818  ARD1; D-arabinitol dehydrogenase (NADP+) [EC:1.1.1.287]
# K00007  dalD; D-arabinitol 4-dehydrogenase [EC:1.1.1.11]
# K09988  lyxA; D-lyxose ketol-isomerase [EC:5.3.1.15]
# K05351  E1.1.1.9; D-xylulose reductase [EC:1.1.1.9]
# K00008  SORD, gutB; L-iditol 2-dehydrogenase [EC:1.1.1.14]
# K22185  xylB; D-xylose 1-dehydrogenase [EC:1.1.1.175]
# K00078  DHDH; dihydrodiol dehydrogenase / D-xylose 1-dehydrogenase (NADP) [EC:1.3.1.20 1.1.1.179]
# K14273  xdh; D-xylose 1-dehydrogenase (NADP+, D-xylono-1,5-lactone-forming) [EC:1.1.1.179]
# K14274  xylC; xylono-1,5-lactonase [EC:3.1.1.110]
# K24442  xacA; D-xylose 1-dehydrogenase (NADP+, D-xylono-1,4-lactone-forming) [EC:1.1.1.424]
# K24443  xacC; D-xylono/L-arabinono-1,4-lactonase [EC:3.1.1.68 3.1.1.15]
# K14275  xad; D-xylonate dehydratase [EC:4.2.1.82]
# K22186  xylD; xylonate dehydratase [EC:4.2.1.82]
# K22396  yjhG, yagF; xylonate dehydratase [EC:4.2.1.82]
# K22397  yjhH, yagE; 2-dehydro-3-deoxy-D-pentonate aldolase [EC:4.1.2.28]
# K14259  kdaD, xacE, kdxD; 2-dehydro-3-deoxy-D-arabinonate dehydratase [EC:4.2.1.141]
# K13877  aldH; 2,5-dioxopentanoate dehydrogenase [EC:1.2.1.26]
# K19588  dopDH; 2,5-dioxopentanoate dehydrogenase [EC:1.2.1.26]
# K22187  xylA; alpha-ketoglutaric semialdehyde dehydrogenase [EC:1.2.1.-]
# K00875  rbtK, FGGY; D-ribulokinase [EC:2.7.1.47]
# K22935  XK1, psk; D-ribulokinase [EC:2.7.1.47]
# K00039  rbtD; ribitol 2-dehydrogenase [EC:1.1.1.56]
# K21680  E1.1.1.137; ribulose-5-phosphate 2-dehydrogenase [EC:1.1.1.137]
# K05352  tarJ; ribitol-5-phosphate 2-dehydrogenase (NADP+) [EC:1.1.1.405]
# K21681  bcs1; ribitol-5-phosphate 2-dehydrogenase (NADP+) / D-ribitol-5-phosphate cytidylyltransferase [EC:1.1.1.405 2.7.7.40]
# K21030  tarI; D-ribitol-5-phosphate cytidylyltransferase [EC:2.7.7.40]
# K21031  ISPD; D-ribitol-5-phosphate cytidylyltransferase [EC:2.7.7.40]
# K01818  fucI; L-fucose/D-arabinose isomerase [EC:5.3.1.25 5.3.1.3]
# K00879  fucK; L-fuculokinase [EC:2.7.1.51]
# K01628  fucA; L-fuculose-phosphate aldolase [EC:4.1.2.17]
# K01218  gmuG; mannan endo-1,4-beta-mannosidase [EC:3.2.1.78]
# K19355  MAN; mannan endo-1,4-beta-mannosidase [EC:3.2.1.78]
# K00847  E2.7.1.4, scrK; fructokinase [EC:2.7.1.4]
# K01809  manA, MPI; mannose-6-phosphate isomerase [EC:5.3.1.8]
# K15916  pgi-pmi; glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]
# K16011  algA, xanB, rfbA, wbpW, pslB; mannose-1-phosphate guanylyltransferase / mannose-6-phosphate isomerase [EC:2.7.7.13 5.3.1.8]
# K17497  PMM; phosphomannomutase [EC:5.4.2.8]
# K01840  manB; phosphomannomutase [EC:5.4.2.8]
# K15778  pmm-pgm; phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2]
# K16881  K16881; mannose-1-phosphate guanylyltransferase / phosphomannomutase [EC:2.7.7.13 5.4.2.8]
# K00971  manC, cpsB; mannose-1-phosphate guanylyltransferase [EC:2.7.7.13]
# K00966  GMPP; mannose-1-phosphate guanylyltransferase [EC:2.7.7.13]
# K01711  gmd, GMDS; GDPmannose 4,6-dehydratase [EC:4.2.1.47]
# K02377  TSTA3, fcl; GDP-L-fucose synthase [EC:1.1.1.271]
# K00976  FPGT; fucose-1-phosphate guanylyltransferase [EC:2.7.7.30]
# K18447  NUDX14; ADP-sugar diphosphatase [EC:3.6.1.21]
# K05305  FUK; fucokinase [EC:2.7.1.52]
# K01818  fucI; L-fucose/D-arabinose isomerase [EC:5.3.1.25 5.3.1.3]
# K00879  fucK; L-fuculokinase [EC:2.7.1.51]
# K01628  fucA; L-fuculose-phosphate aldolase [EC:4.1.2.17]
# K00064  E1.1.1.122; D-threo-aldose 1-dehydrogenase [EC:1.1.1.122]
# K18333  K18333; L-fucose dehydrogenase
# K07046  K07046; L-fuconolactonase [EC:3.1.1.-]
# K18334  fucD; L-fuconate dehydratase [EC:4.2.1.68]
# K18335  K18335; 2-keto-3-deoxy-L-fuconate dehydrogenase [EC:1.1.1.-]
# K18336  lra6; 2,4-didehydro-3-deoxy-L-rhamnonate hydrolase [EC:3.7.1.26]
# K18337  LRA1; L-rhamnose 1-dehydrogenase [EC:1.1.1.378 1.1.1.377 1.1.1.173]
# K18338  LRA2; L-rhamnono-1,4-lactonase [EC:3.1.1.65]
# K12661  LRA3, rhmD; L-rhamnonate dehydratase [EC:4.2.1.90]
# K18339  LRA4; 2-keto-3-deoxy-L-rhamnonate aldolase [EC:4.1.2.53]
# K12660  rhmA; 2-dehydro-3-deoxy-L-rhamnonate aldolase [EC:4.1.2.53]
# K01813  rhaA; L-rhamnose isomerase [EC:5.3.1.14]
# K21883  lra5; 2-dehydro-3-deoxy-L-rhamnonate dehydrogenase (NAD+) [EC:1.1.1.401]
# K01820  rhaA; L-rhamnose isomerase / sugar isomerase [EC:5.3.1.14 5.3.1.-]
# K00848  rhaB; rhamnulokinase [EC:2.7.1.5]
# K01629  rhaD; rhamnulose-1-phosphate aldolase [EC:4.1.2.19]
# K05947  E2.4.1.217; mannosyl-3-phosphoglycerate synthase [EC:2.4.1.217]
# K07026  E3.1.3.70; mannosyl-3-phosphoglycerate phosphatase [EC:3.1.3.70]
# K18818  mgs; mannosylglycerate synthase [EC:2.4.1.269]
# K00844  HK; hexokinase [EC:2.7.1.1]
# K24182  PFK9; 6-phosphofructokinase [EC:2.7.1.11]
# K00850  pfkA, PFK; 6-phosphofructokinase 1 [EC:2.7.1.11]
# K16370  pfkB; 6-phosphofructokinase 2 [EC:2.7.1.11]
# K21071  pfk, pfp; ATP-dependent phosphofructokinase / diphosphate-dependent phosphofructokinase [EC:2.7.1.11 2.7.1.90]
# K00895  pfp, PFP; diphosphate-dependent phosphofructokinase [EC:2.7.1.90]
# K03841  FBP, fbp; fructose-1,6-bisphosphatase I [EC:3.1.3.11]
# K02446  glpX; fructose-1,6-bisphosphatase II [EC:3.1.3.11]
# K11532  glpX-SEBP; fructose-1,6-bisphosphatase II / sedoheptulose-1,7-bisphosphatase [EC:3.1.3.11 3.1.3.37]
# K01086  fbp-SEBP; fructose-1,6-bisphosphatase I / sedoheptulose-1,7-bisphosphatase [EC:3.1.3.11 3.1.3.37]
# K04041  fbp3; fructose-1,6-bisphosphatase III [EC:3.1.3.11]
# K19028  PFKFB1; 6-phosphofructo-2-kinase / fructose-2,6-biphosphatase 1 [EC:2.7.1.105 3.1.3.46]
# K19029  PFKFB2; 6-phosphofructo-2-kinase / fructose-2,6-biphosphatase 2 [EC:2.7.1.105 3.1.3.46]
# K01103  PFKFB3; 6-phosphofructo-2-kinase / fructose-2,6-biphosphatase 3 [EC:2.7.1.105 3.1.3.46]
# K19030  PFKFB4; 6-phosphofructo-2-kinase / fructose-2,6-biphosphatase 4 [EC:2.7.1.105 3.1.3.46]
# K00900  E2.7.1.105, PFK; 6-phosphofructo-2-kinase [EC:2.7.1.105]
# K14634  TIGAR; fructose-2,6-bisphosphatase [EC:3.1.3.46]
# K00009  mtlD; mannitol-1-phosphate 5-dehydrogenase [EC:1.1.1.17]
# K00068  srlD; sorbitol-6-phosphate 2-dehydrogenase [EC:1.1.1.140]
# K19956  sorE; L-sorbose 1-phosphate reductase [EC:1.1.1.-]
# K00846  KHK; ketohexokinase [EC:2.7.1.3]
# K00882  fruK; 1-phosphofructokinase [EC:2.7.1.56]
# K00008  SORD, gutB; L-iditol 2-dehydrogenase [EC:1.1.1.14]
# K00011  AKR1B; aldehyde reductase [EC:1.1.1.21]
# K00594  xyoA, aldO; alditol oxidase [EC:1.1.3.41]
# K01805  xylA; xylose isomerase [EC:5.3.1.5]
# K08261  E1.1.99.21; D-sorbitol dehydrogenase (acceptor) [EC:1.1.99.21]
# K17742  SOU1; sorbose reductase [EC:1.1.1.289]
# K19633  sr; sorbose reductase [EC:1.1.1.289]
# K00045  E1.1.1.67, mtlK; mannitol 2-dehydrogenase [EC:1.1.1.67]
# K00007  dalD; D-arabinitol 4-dehydrogenase [EC:1.1.1.11]
# K00066  algD; GDP-mannose 6-dehydrogenase [EC:1.1.1.132]
# K19290  alg8; mannuronan synthase [EC:2.4.1.33]
# K19291  alg44; mannuronan synthase [EC:2.4.1.33]
# K01795  algG; mannuronan 5-epimerase [EC:5.1.3.37]
# K01729  algL; poly(beta-D-mannuronate) lyase [EC:4.2.2.3]
# K01623  ALDO; fructose-bisphosphate aldolase, class I [EC:4.1.2.13]
# K11645  fbaB; fructose-bisphosphate aldolase, class I [EC:4.1.2.13]
# K01624  FBA, fbaA; fructose-bisphosphate aldolase, class II [EC:4.1.2.13]
# K01622  K01622; fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]
# K16305  K16305; fructose-bisphosphate aldolase / 6-deoxy-5-ketofructose 1-phosphate synthase [EC:4.1.2.13 2.2.1.11]
# K16306  K16306; fructose-bisphosphate aldolase / 2-amino-3,7-dideoxy-D-threo-hept-6-ulosonate synthase [EC:4.1.2.13 2.2.1.10]
# K01803  TPI, tpiA; triosephosphate isomerase (TIM) [EC:5.3.1.1]
# K00863  DAK, TKFC; triose/dihydroxyacetone kinase / FAD-AMP lyase (cyclizing) [EC:2.7.1.28 2.7.1.29 4.6.1.15]
# K03332  fruA; fructan beta-fructosidase [EC:3.2.1.80]
# K22252  tld; GDP-6-deoxy-D-talose 4-dehydrogenase [EC:1.1.1.135]
# K15856  rmd; GDP-4-dehydro-6-deoxy-D-mannose reductase [EC:1.1.1.281]
# K00881  alsK; allose kinase [EC:2.7.1.55]
# K01808  rpiB; ribose 5-phosphate isomerase B [EC:5.3.1.6]
# K17195  alsE; D-allulose-6-phosphate 3-epimerase [EC:5.1.3.-]
# K02768  fruB; fructose PTS system EIIA component [EC:2.7.1.202]
# K02769  fruAb; fructose PTS system EIIB component [EC:2.7.1.202]
# K02770  fruA; fructose PTS system EIIBC or EIIC component [EC:2.7.1.202]
# K11194  levD; fructose PTS system EIIA component [EC:2.7.1.202]
# K11195  levE; fructose PTS system EIIB component [EC:2.7.1.202]
# K11196  levF; fructose PTS system EIIC component
# K02771  levG; fructose PTS system EIID component
# K02793  manXa; mannose PTS system EIIA component [EC:2.7.1.191]
# K02794  manX; mannose PTS system EIIAB component [EC:2.7.1.191]
# K02795  manY; mannose PTS system EIIC component
# K02796  manZ; mannose PTS system EIID component
# K25814  manP; mannose PTS system EIIBCA component [EC:2.7.1.191]
# K02798  cmtB; mannitol PTS system EIIA component [EC:2.7.1.197]
# K02800  mtlA, cmtA; mannitol PTS system EIICBA or EIICB component [EC:2.7.1.197]
# K19270  hxpA; mannitol-1-/sugar-/sorbitol-6-phosphatase [EC:3.1.3.22 3.1.3.23 3.1.3.50]
# K24204  hxpB; mannitol-1-/sugar-/sorbitol-6-/2-deoxyglucose-6-phosphatase [EC:3.1.3.22 3.1.3.23 3.1.3.50 3.1.3.68]
# K02781  srlB; glucitol/sorbitol PTS system EIIA component [EC:2.7.1.198]
# K02782  srlE; glucitol/sorbitol PTS system EIIB component [EC:2.7.1.198]
# K02783  srlA; glucitol/sorbitol PTS system EIIC component
# K02812  sorF, sorA; sorbose PTS system EIIA component [EC:2.7.1.206]
# K02813  sorB; sorbose PTS system EIIB component [EC:2.7.1.206]
# K02814  sorA, sorC; sorbose PTS system EIIC component
# K02815  sorM, sorD; sorbose PTS system EIID component
# K01785  galM, GALM; aldose 1-epimerase [EC:5.1.3.3]
# K00849  galK; galactokinase [EC:2.7.1.6]
# K00965  galT, GALT; UDPglucose--hexose-1-phosphate uridylyltransferase [EC:2.7.7.12]
# K01784  galE, GALE; UDP-glucose 4-epimerase [EC:5.1.3.2]
# K17716  capD; UDP-glucose 4-epimerase [EC:5.1.3.2]
# K00963  UGP2, galU, galF; UTP--glucose-1-phosphate uridylyltransferase [EC:2.7.7.9]
# K01835  pgm; phosphoglucomutase [EC:5.4.2.2]
# K15778  pmm-pgm; phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2]
# K15779  PGM2; phosphoglucomutase / phosphopentomutase [EC:5.4.2.2 5.4.2.7]
# K00844  HK; hexokinase [EC:2.7.1.1]
# K12407  GCK; glucokinase [EC:2.7.1.2]
# K00845  glk; glucokinase [EC:2.7.1.2]
# K25026  glk; glucokinase [EC:2.7.1.2]
# K01084  G6PC; glucose-6-phosphatase [EC:3.1.3.9]
# K01190  lacZ; beta-galactosidase [EC:3.2.1.23]
# K12111  ebgA; evolved beta-galactosidase subunit alpha [EC:3.2.1.23]
# K12112  ebgC; evolved beta-galactosidase subunit beta
# K12308  bgaB, lacA; beta-galactosidase [EC:3.2.1.23]
# K12309  GLB1, ELNR1; beta-galactosidase [EC:3.2.1.23]
# K01229  LCT; lactase-phlorizin hydrolase [EC:3.2.1.108 3.2.1.62]
# K00704  LALBA; alpha-lactalbumin [EC:2.4.1.22]
# K07966  B4GALT1; beta-1,4-galactosyltransferase 1 [EC:2.4.1.22 2.4.1.90 2.4.1.38 2.4.1.-]
# K07967  B4GALT2; beta-1,4-galactosyltransferase 2 [EC:2.4.1.22 2.4.1.90 2.4.1.38 2.4.1.-]
# K12447  USP; UDP-sugar pyrophosphorylase [EC:2.7.7.64]
# K01854  glf; UDP-galactopyranose mutase [EC:5.4.99.9]
# K18819  GOLS; inositol 3-alpha-galactosyltransferase [EC:2.4.1.123]
# K06617  E2.4.1.82; raffinose synthase [EC:2.4.1.82]
# K01189  GLA; alpha-galactosidase [EC:3.2.1.22]
# K07406  melA; alpha-galactosidase [EC:3.2.1.22]
# K07407  E3.2.1.22B, galA, rafA; alpha-galactosidase [EC:3.2.1.22]
# K00011  AKR1B; aldehyde reductase [EC:1.1.1.21]
# K02773  gatA, sgcA; galactitol PTS system EIIA component [EC:2.7.1.200]
# K02774  gatB, sgcB; galactitol PTS system EIIB component [EC:2.7.1.200]
# K02775  gatC, sgcC; galactitol PTS system EIIC component
# K00094  E1.1.1.251, gatD; galactitol-1-phosphate 5-dehydrogenase [EC:1.1.1.251]
# K21620  sorbD; galactitol 2-dehydrogenase [EC:1.1.1.16]
# K21621  fk; tagatose kinase [EC:2.7.1.101]
# K21622  tag6PK; D-tagatose 6-phosphate 4-epimerase [EC:5.1.3.40]
# K00917  lacC; tagatose 6-phosphate kinase [EC:2.7.1.144]
# K00850  pfkA, PFK; 6-phosphofructokinase 1 [EC:2.7.1.11]
# K16370  pfkB; 6-phosphofructokinase 2 [EC:2.7.1.11]
# K21071  pfk, pfp; ATP-dependent phosphofructokinase / diphosphate-dependent phosphofructokinase [EC:2.7.1.11 2.7.1.90]
# K01635  lacD; tagatose 1,6-diphosphate aldolase [EC:4.1.2.40]
# K08302  gatY-kbaY; tagatose 1,6-diphosphate aldolase GatY/KbaY [EC:4.1.2.40]
# K16371  gatZ-kbaZ; D-tagatose-1,6-bisphosphate aldolase subunit GatZ/KbaZ
# K00035  gal; D-galactose 1-dehydrogenase [EC:1.1.1.48]
# K22215  galD; galactose dehydrogenase [EC:1.1.1.48 1.1.1.120]
# K18124  gdh2, gdhA; glucose/galactose 1-dehydrogenase (NADP+) [EC:1.1.1.360]
# K18125  ssgdh; aldose 1-dehydrogenase [NAD(P)+] [EC:1.1.1.359]
# K04618  GAOA; galactose oxidase [EC:1.1.3.9]
# K01684  dgoD; galactonate dehydratase [EC:4.2.1.6]
# K05308  gnaD; gluconate/galactonate dehydratase [EC:4.2.1.140]
# K11395  kdpgA; 2-dehydro-3-deoxy-phosphogluconate/2-dehydro-3-deoxy-6-phosphogalactonate aldolase [EC:4.1.2.55]
# K18127  kdgA; 2-dehydro-3-deoxy-D-gluconate aldolase [EC:4.1.2.51]
# K00883  dgoK; 2-dehydro-3-deoxygalactonokinase [EC:2.7.1.58]
# K18126  sskdgK; 2-dehydro-3-deoxygluconokinase / 2-dehydro-3-deoxygalactonokinase [EC:2.7.1.178]
# K01631  dgoA; 2-dehydro-3-deoxyphosphogalactonate aldolase [EC:4.1.2.21]
# K01819  E5.3.1.26, lacA, lacB; galactose-6-phosphate isomerase [EC:5.3.1.26]
# K01220  E3.2.1.85, lacG; 6-phospho-beta-galactosidase [EC:3.2.1.85]
# K02786  lacF; lactose PTS system EIIA component [EC:2.7.1.207]
# K02788  lacE; lactose PTS system EIICB component [EC:2.7.1.207]
# K01193  INV, sacA; beta-fructofuranosidase [EC:3.2.1.26]
# K06611  E2.4.1.67; stachyose synthetase [EC:2.4.1.67]
# K12047  MGAM; maltase-glucoamylase [EC:3.2.1.20 3.2.1.3]
# K01187  malZ; alpha-glucosidase [EC:3.2.1.20]
# K12316  GAA; lysosomal alpha-glucosidase [EC:3.2.1.20]
# K12317  GANC; neutral alpha-glucosidase C [EC:3.2.1.20]
# K01182  IMA, malL; oligo-1,6-glucosidase [EC:3.2.1.10]
# K01203  SI; sucrase-isomaltase [EC:3.2.1.48 3.2.1.10]
# K02744  agaF; N-acetylgalactosamine PTS system EIIA component [EC:2.7.1.-]
# K02745  agaV; N-acetylgalactosamine PTS system EIIB component [EC:2.7.1.-]
# K02746  agaW; N-acetylgalactosamine PTS system EIIC component
# K02747  agaE; N-acetylgalactosamine PTS system EIID component
# K02079  agaA; N-acetylgalactosamine-6-phosphate deacetylase [EC:3.5.1.25]
# K02082  agaS; D-galactosamine 6-phosphate deaminase/isomerase [EC:3.5.99.-]
# K10984  agaB; galactosamine PTS system EIIB component [EC:2.7.1.-]
# K10985  agaC; galactosamine PTS system EIIC component
# K10986  agaD; galactosamine PTS system EIID component
# K00012  UGDH, ugd; UDPglucose 6-dehydrogenase [EC:1.1.1.22]
# K12447  USP; UDP-sugar pyrophosphorylase [EC:2.7.7.64]
# K16190  GLCAK; glucuronokinase [EC:2.7.1.43]
# K00699  UGT; glucuronosyltransferase [EC:2.4.1.17]
# K01195  uidA, GUSB; beta-glucuronidase [EC:3.2.1.31]
# K14756  KL; klotho [EC:3.2.1.31]
# K00469  MIOX; inositol oxygenase [EC:1.13.99.1]
# K00002  AKR1A1, adh; alcohol dehydrogenase (NADP+) [EC:1.1.1.2]
# K01053  gnl, RGN; gluconolactonase [EC:3.1.1.17]
# K00103  GULO; L-gulonolactone oxidase [EC:1.1.3.8]
# K10046  GME; GDP-D-mannose 3', 5'-epimerase [EC:5.1.3.18 5.1.3.-]
# K14190  VTC2_5; GDP-L-galactose phosphorylase [EC:2.7.7.69]
# K10047  VTC4; inositol-phosphate phosphatase / L-galactose 1-phosphate phosphatase [EC:3.1.3.25 3.1.3.93]
# K18649  IMPL2; inositol-phosphate phosphatase / L-galactose 1-phosphate phosphatase / histidinol-phosphatase [EC:3.1.3.25 3.1.3.93 3.1.3.15]
# K00064  E1.1.1.122; D-threo-aldose 1-dehydrogenase [EC:1.1.1.122]
# K17744  GalDH; L-galactose dehydrogenase [EC:1.1.1.316]
# K00225  GLDH; L-galactono-1,4-lactone dehydrogenase [EC:1.3.2.3]
# K08679  GAE, cap1J; UDP-glucuronate 4-epimerase [EC:5.1.3.6]
# K19642  GALUR; D-galacturonate reductase [EC:1.1.1.365]
# K23003  lgaA; L-galactose dehydrogenase [EC:1.1.1.-]
# K23004  lgaB; L-galactono-1,5-lactonase [EC:3.1.1.-]
# K23005  lgaC; L-galactonate 5-dehydrogenase [EC:1.1.1.414]
# K23007  lgoD; L-galactonate 5-dehydrogenase [EC:1.1.1.414]
# K02821  ulaC, sgaA; ascorbate PTS system EIIA or EIIAB component [EC:2.7.1.194]
# K02822  ulaB, sgaB; ascorbate PTS system EIIB component [EC:2.7.1.194]
# K03475  ulaA, sgaT; ascorbate PTS system EIIC component
# K03476  ulaG; L-ascorbate 6-phosphate lactonase [EC:3.1.1.-]
# K03078  ulaD, sgaH, sgbH; 3-dehydro-L-gulonate-6-phosphate decarboxylase [EC:4.1.1.85]
# K03079  ulaE, sgaU, sgbU; L-ribulose-5-phosphate 3-epimerase [EC:5.1.3.22]
# K03077  araD, ulaF, sgaE, sgbE; L-ribulose-5-phosphate 4-epimerase [EC:5.1.3.4]
# K08232  E1.6.5.4; monodehydroascorbate reductase (NADH) [EC:1.6.5.4]
# K00434  E1.11.1.11; L-ascorbate peroxidase [EC:1.11.1.11]
# K21888  DHAR; glutathione dehydrogenase/transferase [EC:1.8.5.1 2.5.1.18]
# K00423  E1.10.3.3; L-ascorbate oxidase [EC:1.10.3.3]
# K08092  dlgD; 3-dehydro-L-gulonate 2-dehydrogenase [EC:1.1.1.130]
# K00880  lyxK; L-xylulokinase [EC:2.7.1.53]
# K00128  ALDH; aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]
# K14085  ALDH7A1; aldehyde dehydrogenase family 7 member A1 [EC:1.2.1.31 1.2.1.8 1.2.1.3]
# K00149  ALDH9A1; aldehyde dehydrogenase family 9 member A1 [EC:1.2.1.47 1.2.1.3]
# K01706  gudD; glucarate dehydratase [EC:4.2.1.40]
# K01630  garL; 2-dehydro-3-deoxyglucarate aldolase [EC:4.1.2.20]
# K00062  ARA2; D-arabinose 1-dehydrogenase [EC:1.1.1.116]
# K00063  ARA1; D-arabinose 1-dehydrogenase [EC:1.1.1.117]
# K00107  ALO; D-arabinono-1,4-lactone oxidase [EC:1.1.3.37]
# K19590  araDH; D-arabinose 1-dehydrogenase (NADP+) [EC:1.1.1.427]
# K01683  araD; D-arabinonate dehydratase [EC:4.2.1.5]
# K14259  kdaD, xacE, kdxD; 2-dehydro-3-deoxy-D-arabinonate dehydratase [EC:4.2.1.141]
# K13873  araA; L-arabinose 1-dehydrogenase [EC:1.1.1.376]
# K19660  araDH; L-arabinose 1-dehydrogenase [NAD(P)+] [EC:1.1.1.376]
# K13874  araB; L-arabinonolactonase [EC:3.1.1.15]
# K24443  xacC; D-xylono/L-arabinono-1,4-lactonase [EC:3.1.1.68 3.1.1.15]
# K13875  araC; L-arabonate dehydrase [EC:4.2.1.25]
# K13876  araD; 2-keto-3-deoxy-L-arabinonate dehydratase [EC:4.2.1.43]
# K25260  lxyD; L-lyxonate dehydratase [EC:4.2.1.176]
# K13877  aldH; 2,5-dioxopentanoate dehydrogenase [EC:1.2.1.26]
# K19588  dopDH; 2,5-dioxopentanoate dehydrogenase [EC:1.2.1.26]
# K01707  kdgD; 5-dehydro-4-deoxyglucarate dehydratase [EC:4.2.1.41]
# K01708  garD; galactarate dehydratase [EC:4.2.1.42]
# K20023  talrD-galrD; L-talarate/galactarate dehydratase [EC:4.2.1.156 4.2.1.42]
# K18981  udh; uronate dehydrogenase [EC:1.1.1.203]
# K18982  gli; D-galactarolactone isomerase [EC:5.4.1.4]
# K18983  gci; D-galactarolactone cycloisomerase [EC:5.5.1.27]
# K02810  scrA, sacP, sacX, ptsS; sucrose PTS system EIIBCA or EIIBC component [EC:2.7.1.211]
# K01193  INV, sacA; beta-fructofuranosidase [EC:3.2.1.26]
# K00696  E2.4.1.14; sucrose-phosphate synthase [EC:2.4.1.14]
# K07024  SPP; sucrose-6-phosphatase [EC:3.1.3.24]
# K00695  SUS; sucrose synthase [EC:2.4.1.13]
# K12047  MGAM; maltase-glucoamylase [EC:3.2.1.20 3.2.1.3]
# K01187  malZ; alpha-glucosidase [EC:3.2.1.20]
# K12316  GAA; lysosomal alpha-glucosidase [EC:3.2.1.20]
# K12317  GANC; neutral alpha-glucosidase C [EC:3.2.1.20]
# K01203  SI; sucrase-isomaltase [EC:3.2.1.48 3.2.1.10]
# K20811  inuJ; inulosucrase [EC:2.4.1.9]
# K00692  sacB; levansucrase [EC:2.4.1.10]
# K18775  lf2; levanbiose-producing levanase [EC:3.2.1.64]
# K01212  sacC, levB; levanase [EC:3.2.1.65]
# K05341  E2.4.1.4; amylosucrase [EC:2.4.1.4]
# K00689  E2.4.1.5; dextransucrase [EC:2.4.1.5]
# K00690  E2.4.1.7; sucrose phosphorylase [EC:2.4.1.7]
# K00963  UGP2, galU, galF; UTP--glucose-1-phosphate uridylyltransferase [EC:2.7.7.9]
# K01513  ENPP1_3, CD203; ectonucleotide pyrophosphatase/phosphodiesterase family member 1/3 [EC:3.1.4.1 3.6.1.9]
# K00706  E2.4.1.34; 1,3-beta-glucan synthase [EC:2.4.1.34]
# K01199  EGLC; glucan endo-1,3-beta-D-glucosidase [EC:3.2.1.39]
# K19891  GN1_2_3; glucan endo-1,3-beta-glucosidase 1/2/3 [EC:3.2.1.39]
# K19892  GN4; glucan endo-1,3-beta-glucosidase 4 [EC:3.2.1.39]
# K19893  GN5_6; glucan endo-1,3-beta-glucosidase 5/6 [EC:3.2.1.39]
# K01210  E3.2.1.58; glucan 1,3-beta-glucosidase [EC:3.2.1.58]
# K01188  E3.2.1.21; beta-glucosidase [EC:3.2.1.21]
# K05349  bglX; beta-glucosidase [EC:3.2.1.21]
# K05350  bglB; beta-glucosidase [EC:3.2.1.21]
# K00694  bcsA; cellulose synthase (UDP-forming) [EC:2.4.1.12]
# K01179  E3.2.1.4; endoglucanase [EC:3.2.1.4]
# K19357  CELB; cellulase [EC:3.2.1.4]
# K01225  CBH1; cellulose 1,4-beta-cellobiosidase [EC:3.2.1.91]
# K19668  CBH2, cbhA; cellulose 1,4-beta-cellobiosidase [EC:3.2.1.91]
# K00702  E2.4.1.20; cellobiose phosphorylase [EC:2.4.1.20]
# K02759  celC, chbA; cellobiose PTS system EIIA component [EC:2.7.1.196 2.7.1.205]
# K02760  celA, chbB; cellobiose PTS system EIIB component [EC:2.7.1.196 2.7.1.205]
# K02761  celB, chbC; cellobiose PTS system EIIC component
# K01222  E3.2.1.86A, celF; 6-phospho-beta-glucosidase [EC:3.2.1.86]
# K01223  E3.2.1.86B, bglA; 6-phospho-beta-glucosidase [EC:3.2.1.86]
# K00978  rfbF; glucose-1-phosphate cytidylyltransferase [EC:2.7.7.33]
# K00975  glgC; glucose-1-phosphate adenylyltransferase [EC:2.7.7.27]
# K18447  NUDX14; ADP-sugar diphosphatase [EC:3.6.1.21]
# K00703  glgA; starch synthase [EC:2.4.1.21]
# K13679  WAXY; granule-bound starch synthase [EC:2.4.1.242]
# K20812  glgA; glycogen synthase [EC:2.4.1.242]
# K00693  GYS; glycogen synthase [EC:2.4.1.11]
# K00750  GYG1, GYG2; glycogenin [EC:2.4.1.186]
# K16150  K16150; glycogen synthase [EC:2.4.1.11]
# K16153  K16153; glycogen phosphorylase/synthase [EC:2.4.1.1 2.4.1.11]
# K00700  GBE1, glgB; 1,4-alpha-glucan branching enzyme [EC:2.4.1.18]
# K16149  K16149; 1,4-alpha-glucan branching enzyme [EC:2.4.1.18]
# K00688  PYG, glgP; glycogen phosphorylase [EC:2.4.1.1]
# K01196  AGL; glycogen debranching enzyme [EC:2.4.1.25 3.2.1.33]
# K02438  glgX; glycogen debranching enzyme [EC:3.2.1.196]
# K01200  pulA; pullulanase [EC:3.2.1.41]
# K01176  AMY, amyA, malS; alpha-amylase [EC:3.2.1.1]
# K07405  E3.2.1.1A; alpha-amylase [EC:3.2.1.1]
# K05343  treS; maltose alpha-D-glucosyltransferase / alpha-amylase [EC:5.4.99.16 3.2.1.1]
# K01177  E3.2.1.2; beta-amylase [EC:3.2.1.2]
# K05992  amyM; maltogenic alpha-amylase [EC:3.2.1.133]
# K01208  cd, ma, nplT; cyclomaltodextrinase / maltogenic alpha-amylase / neopullulanase [EC:3.2.1.54 3.2.1.133 3.2.1.135]
# K01178  SGA1; glucoamylase [EC:3.2.1.3]
# K21574  susB; glucan 1,4-alpha-glucosidase [EC:3.2.1.3]
# K01182  IMA, malL; oligo-1,6-glucosidase [EC:3.2.1.10]
# K05988  dexA; dextranase [EC:3.2.1.11]
# K00705  malQ; 4-alpha-glucanotransferase [EC:2.4.1.25]
# K22451  jgt; 4-alpha-glucanotransferase [EC:2.4.1.25]
# K16146  pep2; maltokinase [EC:2.7.1.175]
# K16147  glgE; starch synthase (maltosyl-transferring) [EC:2.4.99.16]
# K16148  glgM; alpha-maltose-1-phosphate synthase [EC:2.4.1.342]
# K00691  mapA; maltose phosphorylase [EC:2.4.1.8]
# K01838  pgmB; beta-phosphoglucomutase [EC:5.4.2.6]
# K02777  crr; sugar PTS system EIIA component [EC:2.7.1.-]
# K02791  malX; maltose/glucose PTS system EIICB component [EC:2.7.1.199 2.7.1.208]
# K20108  malT; maltose PTS system EIICB or EIICBA component [EC:2.7.1.208]
# K02750  glvC, malP, aglA; alpha-glucoside PTS system EIICB component [EC:2.7.1.208 2.7.1.-]
# K06896  mapP; maltose 6'-phosphate phosphatase [EC:3.1.3.90]
# K01232  glvA; maltose-6'-phosphate glucosidase [EC:3.2.1.122]
# K00701  cgt; cyclomaltodextrin glucanotransferase [EC:2.4.1.19]
# K01214  ISA, treX; isoamylase [EC:3.2.1.68]
# K06044  treY, glgY; (1->4)-alpha-D-glucan 1-alpha-D-glucosylmutase [EC:5.4.99.15]
# K01236  treZ, glgZ; maltooligosyltrehalose trehalohydrolase [EC:3.2.1.141]
# K13057  treT; trehalose synthase [EC:2.4.1.245]
# K00697  otsA; trehalose 6-phosphate synthase [EC:2.4.1.15 2.4.1.347]
# K01087  otsB; trehalose 6-phosphate phosphatase [EC:3.1.3.12]
# K16055  TPS; trehalose 6-phosphate synthase/phosphatase [EC:2.4.1.15 3.1.3.12]
# K22337  TSL1, TPS3; trehalose 6-phosphate synthase complex regulatory subunit
# K01194  TREH, treA, treF; alpha,alpha-trehalase [EC:3.2.1.28]
# K22934  E3.2.1.28; alpha,alpha-trehalase [EC:3.2.1.28]
# K05342  treP; alpha,alpha-trehalose phosphorylase [EC:2.4.1.64]
# K02819  treB, treP; trehalose PTS system EIIBC or EIIBCA component [EC:2.7.1.201]
# K01226  treC; trehalose-6-phosphate hydrolase [EC:3.2.1.93]
# K01835  pgm; phosphoglucomutase [EC:5.4.2.2]
# K15778  pmm-pgm; phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2]
# K15779  PGM2; phosphoglucomutase / phosphopentomutase [EC:5.4.2.2 5.4.2.7]
# K00844  HK; hexokinase [EC:2.7.1.1]
# K12407  GCK; glucokinase [EC:2.7.1.2]
# K00845  glk; glucokinase [EC:2.7.1.2]
# K25026  glk; glucokinase [EC:2.7.1.2]
# K01084  G6PC; glucose-6-phosphatase [EC:3.1.3.9]
# K11809  PGM2L1; glucose-1,6-bisphosphate synthase [EC:2.7.1.106]
# K01810  GPI, pgi; glucose-6-phosphate isomerase [EC:5.3.1.9]
# K06859  pgi1; glucose-6-phosphate isomerase, archaeal [EC:5.3.1.9]
# K13810  tal-pgi; transaldolase / glucose-6-phosphate isomerase [EC:2.2.1.2 5.3.1.9]
# K15916  pgi-pmi; glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]
# K00847  E2.7.1.4, scrK; fructokinase [EC:2.7.1.4]
# K01183  E3.2.1.14; chitinase [EC:3.2.1.14]
# K20547  CHIB; basic endochitinase B [EC:3.2.1.14]
# K13381  chiA; bifunctional chitinase/lysozyme [EC:3.2.1.14 3.2.1.17]
# K01207  nagZ; beta-N-acetylhexosaminidase [EC:3.2.1.52]
# K12373  HEXA_B; hexosaminidase [EC:3.2.1.52]
# K18675  chbP; N,N'-diacetylchitobiose phosphorylase [EC:2.4.1.280]
# K01452  E3.5.1.41; chitin deacetylase [EC:3.5.1.41]
# K01233  csn; chitosanase [EC:3.2.1.132]
# K15855  csxA; exo-1,4-beta-D-glucosaminidase [EC:3.2.1.165]
# K02777  crr; sugar PTS system EIIA component [EC:2.7.1.-]
# K02804  nagE; N-acetylglucosamine PTS system EIICBA or EIICB component [EC:2.7.1.193]
# K00884  NAGK, nagK; N-acetylglucosamine kinase [EC:2.7.1.59]
# K01443  nagA, AMDHD2; N-acetylglucosamine-6-phosphate deacetylase [EC:3.5.1.25]
# K02564  nagB, GNPDA; glucosamine-6-phosphate deaminase [EC:3.5.99.6]
# K02765  gamP; D-glucosamine PTS system EIICBA component [EC:2.7.1.-]
# K00844  HK; hexokinase [EC:2.7.1.1]
# K18676  gspK; glucosamine kinase [EC:2.7.1.8]
# K00847  E2.7.1.4, scrK; fructokinase [EC:2.7.1.4]
# K00820  glmS, GFPT; glutamine---fructose-6-phosphate transaminase (isomerizing) [EC:2.6.1.16]
# K00621  GNPNAT1, GNA1; glucosamine-phosphate N-acetyltransferase [EC:2.3.1.4]
# K01836  PGM3; phosphoacetylglucosamine mutase [EC:5.4.2.3]
# K03431  glmM; phosphoglucosamine mutase [EC:5.4.2.10]
# K18674  GALK2; N-acetylgalactosamine kinase [EC:2.7.1.157]
# K04042  glmU; bifunctional UDP-N-acetylglucosamine pyrophosphorylase / glucosamine-1-phosphate N-acetyltransferase [EC:2.7.7.23 2.3.1.157]
# K11528  glmU; UDP-N-acetylglucosamine pyrophosphorylase [EC:2.7.7.23]
# K00972  UAP1; UDP-N-acetylglucosamine/UDP-N-acetylgalactosamine diphosphorylase [EC:2.7.7.23 2.7.7.83]
# ...
# K21830  pchP; phosphorylcholine phosphatase
# K22282  FAXDC2; fatty acid hydroxylase domain-containing protein 2
# K22618  olsE; ornithine lipid hydroxylase
# K25232  fakB; fatty acid kinase fatty acid binding subunit
# K03647  nrdI; protein involved in ribonucleotide reduction
# K15049  ENDOD1; endonuclease domain-containing 1 protein
# K15051  endA; DNA-entry nuclease
# K24196  PRTFDC1; phosphoribosyltransferase domain-containing protein 1
# K10795  prdD; D-proline reductase (dithiol)-stabilizing protein PrdD
# K10796  prdE; D-proline reductase (dithiol)-stabilizing protein PrdE
# K06203  cysZ; CysZ protein
# K04023  eutH; ethanolamine transporter
# K04024  eutJ; ethanolamine utilization protein EutJ
# K04025  eutK; ethanolamine utilization protein EutK
# K04026  eutL; ethanolamine utilization protein EutL
# K04027  eutM; ethanolamine utilization protein EutM
# K04028  eutN; ethanolamine utilization protein EutN
# K04029  eutP; ethanolamine utilization protein EutP
# K04030  eutQ; ethanolamine utilization protein EutQ
# K04031  eutS; ethanolamine utilization protein EutS
# K08234  yaeR; glyoxylase I family protein
# K11325  K11325; L-cysteine/cystine lyase
# K05806  leuL; leu operon leader peptide
# K14054  mpaA; murein peptide amidase A
# K16613  OAZ2; ornithine decarboxylase antizyme 2
# K18802  DUG3; glutamine amidotransferase
# K06997  yggS, PROSC; PLP dependent protein
# K19625  RLBP1; retinaldehyde-binding protein 1
# K21700  bauB; beta-alanine degradation protein BauB
# K22366  SELENOT; thioredoxin reductase-like selenoprotein T
# K22479  argA; N-acetyltransferase
# K19421  epsC; polysaccharide biosynthesis protein EpsC
# K12547  plyA; polysaccharidase protein
# K13620  wcaD; putative colanic acid polymerase
# K03208  wcaI; putative colanic acid biosynthesis glycosyltransferase WcaI
# K16560  exoH; succinoglycan biosynthesis protein ExoH
# K16561  exoI; succinoglycan biosynthesis protein ExoI
# K16563  exoV; succinoglycan biosynthesis protein ExoV
# K16565  exoX, syrA; exopolysaccharide production regulatory protein
# K16566  exoY; exopolysaccharide production protein ExoY
# K16567  exoQ; exopolysaccharide production protein ExoQ
# K16568  exoZ; exopolysaccharide production protein ExoZ
# K16705  tuaE; teichuronic acid biosynthesis protein TuaE
# K16706  tuaF; teichuronic acid biosynthesis protein TuaF
# K16707  amsG; UDP-galactose-lipid carrier transferase
# K16708  amsC; amylovoran biosynthesis protein AmsC
# K16709  amsF; amylovoran biosynthesis protein AmsF
# K16710  wcaK, amsJ; colanic acid/amylovoran biosynthesis protein WcaK/AmsJ
# K16711  wcaM; colanic acid biosynthesis protein WcaM
# K19292  algK; alginate biosynthesis protein AlgK
# K19293  algX; alginate biosynthesis protein AlgX
# K19294  algI; alginate O-acetyltransferase complex protein AlgI
# K19295  algJ; alginate O-acetyltransferase complex protein AlgJ
# K19296  algF; alginate O-acetyltransferase complex protein AlgF
# K08992  lapA; lipopolysaccharide assembly protein A
# K19804  lapB; lipopolysaccharide assembly protein B
# K21461  icaD; poly-beta-1,6-N-acetyl-D-glucosamine synthesis protein
# K21462  icaC; probable poly-beta-1,6-N-acetyl-D-glucosamine export protein
# K21687  rpfA; resuscitation-promoting factor RpfA
# K21688  rpfB; resuscitation-promoting factor RpfB
# K21689  rpfC; resuscitation-promoting factor RpfC
# K21690  rpfD; resuscitation-promoting factor RpfD
# K21691  rpfE; resuscitation-promoting factor RpfE
# K22914  tviA; Vi polysaccharide biosynthesis protein TviA
# K22915  tviD; Vi polysaccharide biosynthesis protein TviD
# K22916  tviE, vipC; Vi polysaccharide biosynthesis protein TviE
# K07027  K07027; glycosyltransferase 2 family protein
# K07270  K07270; glycosyl transferase, family 25
# K20541  bcsB; cellulose synthase operon protein B
# K22907  ppgS; polyprenyl-phospho-N-acetylgalactosaminyl synthase
# K23877  AXY4, AXY4L; xyloglucan O-acetyltransferase
# K24698  mftF; mycofactocin glycosyltransferase
# K02173  yggC; putative kinase
# K02234  cobW; cobalamin biosynthesis protein CobW
# K02498  hemY; HemY protein
# K24868  nirJ; heme d1 biosynthesis protein
# K02859  ribT; riboflavin biosynthesis RibT protein
# K03688  ubiB, aarF; ubiquinone biosynthesis protein
# K03690  ubiJ; ubiquinone biosynthesis accessory factor UbiJ
# K09806  ubiK; ubiquinone biosynthesis accessory factor UbiK
# K24843  ubiT; O2-independent ubiquinone biosynthesis accessory factor UbiT
# K03753  mobB; molybdopterin-guanine dinucleotide biosynthesis adapter protein
# K06049  bchO; magnesium chelatase accessory protein
# K13580  K13580; magnesium chelatase subunit ChlD-like protein
# K12942  abgT; aminobenzoyl-glutamate transport protein
# K12258  GC; vitamin D-binding protein
# K18586  COQ4; ubiquinone biosynthesis protein COQ4
# K18587  COQ9; ubiquinone biosynthesis protein COQ9
# K18588  COQ10; coenzyme Q-binding protein COQ10
# K24265  PANK4; bifunctional damage-control phosphatase, subfamily II, fusion protein
# K24455  TTPA; alpha-tocopherol transfer protein
# K24694  mftA; mycofactocin precursor peptide MftA
# K24695  mftB; mycofactocin biosynthesis protein MftB
# K21824  K21824; oplophorus-luciferin 2-monooxygenase non-catalytic subunit
# K21324  mdpK; tert-butyl alcohol monooxygenase/tert-amyl alcohol desaturase reductase
# K21446  TENA; tenellin biosynthesis cytochrome P450 monooxygenase
# K21296  TENB; tenellin biosynthesis cytochrome P450 monooxygenase
# K21447  AZAI; azaphilone biosynthesis cytochrome P450 monooxygenase
# K21448  AFVE; aflavarin biosynthesis cytochrome P450 monooxygenase
# K21476  LEPD; leporin biosynthesis cytochrome P450 monooxygenase
# K03932  lpqC; polyhydroxybutyrate depolymerase
# K04753  sufI; suppressor of ftsI
# K05558  K05558; pyridoxamine 5'-phosphate oxidase family protein
# K11047  cylX; CylX protein
# K11048  cylD; CylD protein
# K11049  cylG; CylG protein
# K11053  cylF; CylF protein
# K11054  cylI; CylI protein
# K11055  cylJ; CylJ protein
# K11056  cylK; CylK protein
# K12706  novC; novobiocin biosynthesis protein NovC
# K18004  pqsL; HQNO biosynthesis monooxygenase PqsL
# K18535  thnA; putative oxidoreductase
# K18536  thnD; putative oxidoreductase
# K18537  thnK; putative methyltransferase
# K18538  thnN; thienamycin biosynthesis protein ThnN
# K18539  thnO; thienamycin biosynthesis protein ThnO
# K19784  chrR, NQR; chromate reductase, NAD(P)H dehydrogenase (quinone)
# K22148  SIDC; ferricrocin synthase
# K22149  SIDI; mevalonyl-CoA ligase
# K22150  SIDH; mevalonyl-CoA hydratase
# K22151  SIDF; N5-hydroxy-L-ornithine N5-transacylase
# K22152  SIDD; fusarinine C synthase
# K22153  SIDG; fusarinine C N2-transacetylase
# K21295  AF510; fumagillin biosynthesis cytochrome P450 monooxygenase
# K22570  AF480; fumagillin biosynthesis dioxygenase
# K22571  AF390; fumagillin biosynthesis methyltransferase
# K22572  AF490; fumagillin biosynthesis stereoselective ketoreductase
# K22573  AF370; fumagillin biosynthesis polyketide synthase
# K22574  AF380; fumagillin biosynthesis transferase
# K22575  AF470; fumagillin biosynthesis monooxygenase
# K22714  pltB_C; polyketide synthase
# K22729  HELC; helvolic acid biosynthesis dehydrogenase/reductase
# K22730  HELD1; helvolic acid biosynthesis C6-acyltransferase
# K22731  HELD2; helvolic acid biosynthesis cytochrome C16-acyltransferase
# K22732  HELE; helvolic acid biosynthesis 3-ketosteroid Delta1-dehydrogenase
# K22739  CHYA; 2-(2-aminopropanamido)benzoic acid synthetase
# K22740  PSOD; pseurotin biosynthesis cytochrome P450 monooxygenase
# K22742  PSOE; pseurotin biosynthesis glutathione S-transferase
# K22743  PSOF; pseurotin biosynthesis epoxidase/methyltransferase
# K22895  cruH; renierapurpurin 18,18'-hydroxylase
# K23376  sbnG; staphyloferrin B biosynthesis citrate synthase
# K23634  ASAA; ankyrin-repeat domain containg transcription coregulator AsaA
# K24084  aidA; quorum-quenching protein AidA
# K24913  ramS, amfS; lanthionine-containing peptide SapB
# K24914  ramC, amfT; probable SapB synthase
# K18064  ACR2; arsenical-resistance protein 2
# K21831  choE; cholinesterase
# K22390  ACP7; acid phosphatase type 7
# K15975  K15975; glyoxalase family protein
# K15977  K15977; putative oxidoreductase
# K06999  K06999; phospholipase/carboxylesterase
# K09181  yfiQ; acetyltransferase
# K24410  tfuA; TfuA protein
# K25263  hpfH; (2S)-3-sulfopropanediol dehydratase activating enzyme
# K25265  hpsH; (2S)-3-sulfopropanediol sulfolyase activating enzyme
# K02466  gutM; glucitol operon activator protein
# K03627  MBF1; putative transcription factor
# K03622  ssh10b; archaea-specific DNA-binding protein
# K03623  yhcO; ribonuclease inhibitor
# K03704  cspA; cold shock protein
# K07591  tdcR; threonine dehydratase operon activator protein
# K04796  RUXX; small nuclear ribonucleoprotein
# K11100  SNRPN, SMN; small nuclear ribonucleoprotein N
# K07740  rsd; regulator of sigma D
# K07741  antB; anti-repressor protein
# K07802  trpL; trp operon leader peptide
# K08278  thrL; thr operon leader peptide
# K15833  hycA; formate hydrogenlyase regulatory protein HycA
# K15834  hycH; formate hydrogenlyase maturation protein HycH
# K02589  nifHD1, nifI1; nitrogen regulatory protein PII 1
# K02590  nifHD2, nifI2; nitrogen regulatory protein PII 2
# K04752  glnK; nitrogen regulatory protein P-II 2
# K16335  TORC; CREB-regulated transcription coactivator
# K16509  spxA; regulatory protein spx
# K18666  ASCC1; activating signal cointegrator complex subunit 1
# K18667  ASCC2; activating signal cointegrator complex subunit 2
# K18774  PNRC1; proline-rich nuclear receptor coactivator 1
# K19325  ZNF592; zinc finger protein 592
# K19432  slrA; anti-repressor of SlrR
# K19495  JAZF1; juxtaposed with another zinc finger protein 1
# K19512  MAMLD1; mastermind-like domain-containing protein 1
# K06959  tex; protein Tex
# K21389  ADN1; adhesion defective protein 1
# K21390  ADN2; adhesion defective protein 2
# K21391  ADN3; adhesion defective protein 3
# K21554  CREBRF, LRF; CREB3 regulatory factor
# K21627  IFH1; protein IFH1
# K21628  MSA1; G1-specific transcription factors activator MSA1
# K21629  MSA2; G1-specific transcription factors activator MSA2
# K21640  nrpRII; global nitrogen regulator NrpRII
# K21753  PASD1; circadian clock protein PASD1
# K22383  IRF2BP; interferon regulatory factor 2-binding protein
# K22388  NAB; NGFI-A-binding protein
# K22403  ZMIZ; zinc finger MIZ domain-containing protein
# K22525  MKL; MKL/myocardin-like protein
# K22526  MYOCD; myocardin
# K22527  CITED1; Cbp/p300-interacting transactivator 1
# K22528  CITED4; Cbp/p300-interacting transactivator 4
# K22649  BCL9, BCL9L; B-cell CLL/lymphoma 9 protein
# K07743  K07743; transcriptional regulator
# K07744  K07744; transcriptional regulator
# K07745  K07745; transcriptional regulator
# K24380  CST10; cystatin-10
# K24397  DAOA; D-amino acid oxidase activator
# K09777  remA; extracellular matrix regulatory protein A
# K24648  remB; extracellular matrix regulatory protein B
# K24724  AES, TLE5; TLE family member 5 (amino-terminal enhancer of split)
# K25826  CBFB; core-binding factor subunit beta
# K20815  NAT2; N-terminal acetyltransferase 2
# K13926  rbbA; ribosome-dependent ATPase
# K16634  RNH1; ribonuclease inhibitor
# K15025  EIF1AD; probable RNA-binding protein EIF1AD
# K07570  GSP13; general stress protein 13
# K07571  K07571; S1 RNA binding domain protein
# K07572  K07572; putative nucleotide binding protein
# K07576  K07576; metallo-beta-lactamase family protein
# K07577  K07577; putative mRNA 3-end processing factor
# K07578  K07578; homologs of the eukaryotic argonaute protein
# K07579  K07579; putative methylase
# K07580  K07580; Zn-ribbon RNA-binding protein
# K07581  K07581; RNA-binding protein
# K07585  K07585; tRNA methyltransferase
# K23048  UNK; RING finger protein unkempt
# K03668  hslJ; heat shock protein HslJ
# K06891  clpS; ATP-dependent Clp protease adaptor protein ClpS
# K19411  mcsA; protein arginine kinase activator
# K03545  tig; trigger factor
# K17247  msrQ; methionine sulfoxide reductase heme-binding subunit
# K02380  fdhE; FdhE protein
# K03187  ureE; urease accessory protein
# K03188  ureF; urease accessory protein
# K03189  ureG; urease accessory protein
# K03190  ureD, ureH; urease accessory protein
# K03192  ureJ; urease accessory protein
# K03664  smpB; SsrA-binding protein
# K04653  hypC; hydrogenase expression/formation protein HypC
# K04654  hypD; hydrogenase expression/formation protein HypD
# K04655  hypE; hydrogenase expression/formation protein HypE
# K04656  hypF; hydrogenase maturation protein HypF
# K07388  K07388; hydrogenase expression/formation protein
# K06191  nrdH; glutaredoxin-like protein NrdH
# K07391  comM; magnesium chelatase family protein
# K07392  PRS2; AAA family ATPase
# K07394  K07394; SM-20-related protein
# K07395  K07395; putative proteasome-type protease
# K07396  K07396; putative protein-disulfide isomerase
# K07397  yhfA; putative redox protein
# K07398  K07398; conserved protein with predicted RNA binding PUA domain
# K07399  resB, ccs1; cytochrome c biogenesis protein
# K07400  nfuA; Fe/S biogenesis protein NfuA
# K07401  K07401; selenoprotein W-related protein
# K07402  xdhC; xanthine dehydrogenase accessory factor
# K07403  nfeD; membrane-bound serine protease (ClpP class)
# K11208  yncG; GST-like protein
# K15367  sseA; secretion system chaperone SseA
# K18984  ssaE; secretion system chaperone SsaE
# K15368  sscA; secretion system chaperone SscA
# K16511  mecA1_2; adapter protein MecA 1/2
# K07443  ybaZ; methylated-DNA-protein-cysteine methyltransferase related protein
# K07445  K07445; putative DNA methylase
# K07449  K07449; similar to archaeal holliday junction resolvase and Mrr protein
# K07450  K07450; putative resolvase
# K01146  xni; protein Xni
# K07453  K07453; putative restriction endonuclease
# K07454  K07454; putative restriction endonuclease
# K06993  K06993; ribonuclease H-related protein
# K03630  radC; DNA repair protein RadC
# K09760  rmuC; DNA recombination protein RmuC
# K07457  K07457; endonuclease III related protein
# K07459  ybjD; putative ATP-dependent endonuclease of the OLD family
# K07460  yraN; putative endonuclease
# K07461  K07461; putative endonuclease
# K07463  K07463; archaea-specific RecJ-like exonuclease
# K07465  K07465; putative RecB family exonuclease
# K04096  smf; DNA processing protein
# K02086  dnaD; DNA replication protein
# K07467  nicK; putative DNA relaxase
# K07357  fimB; type 1 fimbriae regulatory protein FimB
# K07358  fimE; type 1 fimbriae regulatory protein FimE
# K07470  sbmC; DNA gyrase inhibitor
# K07472  TIP49; TBP-interacting protein
# K07474  xtmA; phage terminase small subunit
# K06909  xtmB; phage terminase large subunit
# K07476  yusF; toprim domain protein
# K07477  K07477; translin
# K07478  ycaJ; putative ATPase
# K07479  yrdD; putative DNA topoisomerase
# K10762  ydaV; putative replication protein
# K14060  pinR; putative DNA-invertase from lambdoid prophage Rac
# K06919  K06919; putative DNA primase/helicase
# K16782  NEURL2; neuralized-like protein 2
# K07505  repA; regulatory protein RepA
# K07500  K07500; DNA endonuclease
# K07501  K07501; 3'-5' exonuclease
# K07480  insB; insertion element IS1 protein InsB
# K07481  K07481; transposase, IS5 family
# K18320  IS15, IS26; transposase, IS6 family
# K07482  K07482; transposase, IS30 family
# K07483  K07483; transposase
# K07484  K07484; transposase
# K07485  K07485; transposase
# K07486  K07486; transposase
# K07487  K07487; transposase
# K07488  K07488; transposase
# K07489  K07489; transposase
# K07491  rayT; REP-associated tyrosine transposase
# K07492  K07492; putative transposase
# K07493  K07493; putative transposase
# K07494  K07494; putative transposase
# K07495  K07495; putative transposase
# K07496  K07496; putative transposase
# K07497  K07497; putative transposase
# K07498  K07498; putative transposase
# K07499  K07499; putative transposase
# K01152  isftu1; isftu1 transposase
# K14059  int; integrase
# K24551  BCAS4; breast carcinoma-amplified sequence 4
# K03969  pspA; phage shock protein A
# K03971  pspD; phage shock protein D
# K03972  pspE; phage shock protein E
# K07504  K07504; predicted type IV restriction endonuclease
# K08274  ltuA; late transcription unit A protein
# K08275  ltuB; late transcription unit B protein
# K09747  ebfC; nucleoid-associated protein EbfC
# K11516  ZFP42, REX1; zinc finger protein 42
# K12038  TRIML1; tripartite motif family-like protein 1
# K12039  TRIML2; tripartite motif family-like protein 2
# K13784  PTMA; prothymosin alpha
# K25656  cry, CRYD; cryptochrome

# %%
total_gene
# Out:
# ['HK',
#  'GCK',
#  'glk',
#  'glk',
#  'GPI, pgi',
#  'pgi1',
#  'tal-pgi',
#  'pgi-pmi',
#  'PFK9',
#  'pfkA, PFK',
#  'pfkB',
#  'pfk, pfp',
#  'pfkC',
#  'pfp, PFP',
#  'FBP, fbp',
#  'glpX',
#  'glpX-SEBP',
#  'fbp-SEBP',
#  'fbp3',
#  'ALDO',
#  'fbaB',
#  'FBA, fbaA',
#  'K01622',
#  'K16305',
#  'K16306',
#  'TPI, tpiA',
#  'GAPDH, gapA',
#  'GAPDHS',
#  'gap2',
#  'PGK, pgk',
#  'PGAM, gpmA',
#  'gpmB',
#  'gpmI',
#  'apgM',
#  'ENO, eno',
#  'PK, pyk',
#  'PKLR',
#  'ppdK',
#  'pps, ppsA',
#  'aceE',
#  'PDHA, pdhA',
#  'PDHB, pdhB',
#  'DLAT, aceF, pdhC',
#  'DLD, lpd, pdhD',
#  'PDHX',
#  'porA',
#  'porB',
#  'porC, porG',
#  'vorG, porG',
#  'porD',
#  'por, nifJ',
#  'korA, oorA, oforA',
#  'korB, oorB, oforB',
#  'LDH, ldh',
#  'PDC, pdc',
#  'ADH1_7',
#  'ADH4',
#  'frmA, ADH5, adhC',
#  'ADH6',
#  'adhE',
#  'adhP',
#  'yiaY',
#  'ADH1',
#  'E1.1.1.1, adh',
#  'AKR1A1, adh',
#  'ahr',
#  'yahK',
#  'mdh1, mxaF',
#  'mdh2, mxaI',
#  'exaA',
#  'eutG',
#  'adhA',
#  'adhB',
#  'ALDH',
#  'ALDH7A1',
#  'ALDH9A1',
#  'ALDH3',
#  'aldB',
#  'ACSS1_2, acs',
#  'AAE7, ACN1',
#  'acdA',
#  'acdB',
#  'acdAB',
#  'galM, GALM',
#  'agp',
#  'yihX',
#  'pgm',
#  'pmm-pgm',
#  'PGM2',
#  'G6PC',
#  'ppgK',
#  'ADPGK',
#  'E5.1.3.15',
#  'BPGM',
#  'MINPP1',
#  'gapor',
#  'gapN',
#  'gapN',
#  'E4.1.1.32, pckA, PCK',
#  'E4.1.1.49, pckA',
#  'E3.2.1.86A, celF',
#  'E3.2.1.86B, bglA',
#  'crr',
#  'ptsG',
#  'malX',
#  'ptsG, glcA, glcB',
#  'ascF',
#  'CS, gltA',
#  'ACLY',
#  'aclA',
#  'aclB',
#  'E2.3.3.3',
#  'ACO, acnA',
#  'acnB',
#  'IDH1, IDH2, icd',
#  'IDH3',
#  'HICDH',
#  'OGDH, sucA',
#  'DLST, sucB',
#  'kgd',
#  'DLD, lpd, pdhD',
#  'korA, oorA, oforA',
#  'korB, oorB, oforB',
#  'korC, oorC',
#  'korD, oorD',
#  'sucD',
#  'sucC',
#  'LSC1',
#  'LSC2',
#  'aarC, cat1',
#  'SDHA, SDH1',
#  'SDHB, SDH2',
#  'SDHC, SDH3',
#  'SDHD, SDH4',
#  'SDH4',
#  'sdhA, frdA',
#  'sdhB, frdB',
#  'sdhC, frdC',
#  'sdhD, frdD',
#  'sdhD, frdD',
#  'sdhD, frdD',
#  'frdA',
#  'frdB',
#  'frdC',
#  'frdD',
#  'E4.2.1.2A, fumA, fumB',
#  'E4.2.1.2AA, fumA',
#  'E4.2.1.2AB, fumB',
#  'E4.2.1.2B, fumC, FH',
#  'fumD',
#  'fumE',
#  'MDH1',
#  'MDH2',
#  'mdh',
#  'mqo',
#  'PC, pyc',
#  'pycA',
#  'pycB',
#  'E4.1.1.49, pckA',
#  'E4.1.1.32, pckA, PCK',
#  'aceE',
#  'PDHA, pdhA',
#  'PDHB, pdhB',
#  'DLAT, aceF, pdhC',
#  'PDHX',
#  'porA',
#  'porB',
#  'porC, porG',
#  'vorG, porG',
#  'porD',
#  'por, nifJ',
#  'GPI, pgi',
#  'pgi1',
#  'tal-pgi',
#  'pgi-pmi',
#  'G6PD, zwf',
#  'azf',
#  'PGLS, pgl, devB',
#  'pgl',
#  'H6PD',
#  'PGD, gnd, gntZ',
#  'rpe, RPE',
#  'E2.2.1.1, tktA, tktB',
#  'E2.2.1.2, talA, talB',
#  'rpiA',
#  'rpiB',
#  'fae-hps',
#  'hxlA',
#  'hxlB',
#  'hps-phi',
#  'xfp, xpk',
#  'deoC, DERA',
#  'rbsK, RBKS',
#  'deoB',
#  'ppm',
#  'pgm',
#  'pmm-pgm',
#  'PGM2',
#  'phnN',
#  'PRPS, prsA',
#  'edd',
#  'eda',
#  'dgaF',
#  'kdpgA',
#  'gapN',
#  'gapN',
#  'gdh',
#  'gdh',
#  'HOX',
#  'gdh2, gdhA',
#  'ssgdh',
#  'GLD',
#  'gdh',
#  'gcd',
#  'gnl, RGN',
#  'E1.1.99.3A',
#  'E1.1.99.3G',
#  'ghrB',
#  'K22229',
#  'kguK',
#  'E1.1.1.43',
#  'idnK, gntK',
#  'gntK',
#  'gnaD',
#  'kdgK',
#  'sskdgK',
#  'kdgA',
#  'aor',
#  'cutA',
#  'cutB',
#  'cutC',
#  'gadh',
#  'gck, gckA, GLYCTK',
#  'E4.3.1.9',
#  'dgaA',
#  'dgaB',
#  'dgaC',
#  'dgaD',
#  'dgaE',
#  'ALDO',
#  'fbaB',
#  'FBA, fbaA',
#  'K01622',
#  'K16305',
#  'K16306',
#  'FBP, fbp',
#  'glpX',
#  'glpX-SEBP',
#  'fbp-SEBP',
#  'fbp3',
#  'PFK9',
#  'pfkA, PFK',
#  'pfkB',
#  'pfk, pfp',
#  'pfkC',
#  'pfp, PFP',
#  'E3.1.1.11',
#  'PLY',
#  'pel',
#  'pelC',
#  'pelW',
#  'pelX',
#  'ogl',
#  'kduI',
#  'kduD',
#  'E3.2.1.15',
#  'E3.2.1.67',
#  'lplD',
#  'uxaC',
#  'uxaB',
#  'uxaA',
#  'uxaA1',
#  'uxaA2',
#  'uxuA',
#  'rspA, manD',
#  'rspB',
#  'uxuB',
#  'uxaE',
#  'GAAA',
#  'gar1',
#  'GAAB, LGD1',
#  'GAAC, LGA1',
#  'GAAD',
#  'uidA, GUSB',
#  'KL',
#  'UGT',
#  'GLCAK',
#  'USP',
#  'UGDH, ugd',
#  'UGP2, galU, galF',
#  'AKR1A1, adh',
#  'CRYL1',
#  'dlgD',
#  'lyxK',
#  'ulaD, sgaH, sgbH',
#  'ulaE, sgaU, sgbU',
#  'araD, ulaF, sgaE, sgbE',
#  'rpe, RPE',
#  'araA',
#  'araB',
#  'E2.7.1.16',
#  'xylB, XYLB',
#  'xylA',
#  'AKR1B',
#  'xyoA, aldO',
#  'XR',
#  'DCXR',
#  'LXRA',
#  'LADA',
#  'LARA',
#  'rhaA',
#  'rhaB',
#  'rhaD',
#  'ARD',
#  'ARD1',
#  'dalD',
#  'lyxA',
#  'E1.1.1.9',
#  'SORD, gutB',
#  'xylB',
#  'DHDH',
#  'xdh',
#  'xylC',
#  'xacA',
#  'xacC',
#  'xad',
#  'xylD',
#  'yjhG, yagF',
#  'yjhH, yagE',
#  'kdaD, xacE, kdxD',
#  'aldH',
#  'dopDH',
#  'xylA',
#  'rbtK, FGGY',
#  'XK1, psk',
#  'rbtD',
#  'E1.1.1.137',
#  'tarJ',
#  'bcs1',
#  'tarI',
#  'ISPD',
#  'fucI',
#  'fucK',
#  'fucA',
#  'gmuG',
#  'MAN',
#  'E2.7.1.4, scrK',
#  'manA, MPI',
#  'pgi-pmi',
#  'algA, xanB, rfbA, wbpW, pslB',
#  'PMM',
#  'manB',
#  'pmm-pgm',
#  'K16881',
#  'manC, cpsB',
#  'GMPP',
#  'gmd, GMDS',
#  'TSTA3, fcl',
#  'FPGT',
#  'NUDX14',
#  'FUK',
#  'fucI',
#  'fucK',
#  'fucA',
#  'E1.1.1.122',
#  'K18333',
#  'K07046',
#  'fucD',
#  'K18335',
#  'lra6',
#  'LRA1',
#  'LRA2',
#  'LRA3, rhmD',
#  'LRA4',
#  'rhmA',
#  'rhaA',
#  'lra5',
#  'rhaA',
#  'rhaB',
#  'rhaD',
#  'E2.4.1.217',
#  'E3.1.3.70',
#  'mgs',
#  'HK',
#  'PFK9',
#  'pfkA, PFK',
#  'pfkB',
#  'pfk, pfp',
#  'pfp, PFP',
#  'FBP, fbp',
#  'glpX',
#  'glpX-SEBP',
#  'fbp-SEBP',
#  'fbp3',
#  'PFKFB1',
#  'PFKFB2',
#  'PFKFB3',
#  'PFKFB4',
#  'E2.7.1.105, PFK',
#  'TIGAR',
#  'mtlD',
#  'srlD',
#  'sorE',
#  'KHK',
#  'fruK',
#  'SORD, gutB',
#  'AKR1B',
#  'xyoA, aldO',
#  'xylA',
#  'E1.1.99.21',
#  'SOU1',
#  'sr',
#  'E1.1.1.67, mtlK',
#  'dalD',
#  'algD',
#  'alg8',
#  'alg44',
#  'algG',
#  'algL',
#  'ALDO',
#  'fbaB',
#  'FBA, fbaA',
#  'K01622',
#  'K16305',
#  'K16306',
#  'TPI, tpiA',
#  'DAK, TKFC',
#  'fruA',
#  'tld',
#  'rmd',
#  'alsK',
#  'rpiB',
#  'alsE',
#  'fruB',
#  'fruAb',
#  'fruA',
#  'levD',
#  'levE',
#  'levF',
#  'levG',
#  'manXa',
#  'manX',
#  'manY',
#  'manZ',
#  'manP',
#  'cmtB',
#  'mtlA, cmtA',
#  'hxpA',
#  'hxpB',
#  'srlB',
#  'srlE',
#  'srlA',
#  'sorF, sorA',
#  'sorB',
#  'sorA, sorC',
#  'sorM, sorD',
#  'galM, GALM',
#  'galK',
#  'galT, GALT',
#  'galE, GALE',
#  'capD',
#  'UGP2, galU, galF',
#  'pgm',
#  'pmm-pgm',
#  'PGM2',
#  'HK',
#  'GCK',
#  'glk',
#  'glk',
#  'G6PC',
#  'lacZ',
#  'ebgA',
#  'ebgC',
#  'bgaB, lacA',
#  'GLB1, ELNR1',
#  'LCT',
#  'LALBA',
#  'B4GALT1',
#  'B4GALT2',
#  'USP',
#  'glf',
#  'GOLS',
#  'E2.4.1.82',
#  'GLA',
#  'melA',
#  'E3.2.1.22B, galA, rafA',
#  'AKR1B',
#  'gatA, sgcA',
#  'gatB, sgcB',
#  'gatC, sgcC',
#  'E1.1.1.251, gatD',
#  'sorbD',
#  'fk',
#  'tag6PK',
#  'lacC',
#  'pfkA, PFK',
#  'pfkB',
#  'pfk, pfp',
#  'lacD',
#  'gatY-kbaY',
#  'gatZ-kbaZ',
#  'gal',
#  'galD',
#  'gdh2, gdhA',
#  'ssgdh',
#  'GAOA',
#  'dgoD',
#  'gnaD',
#  'kdpgA',
#  'kdgA',
#  'dgoK',
#  'sskdgK',
#  'dgoA',
#  'E5.3.1.26, lacA, lacB',
#  'E3.2.1.85, lacG',
#  'lacF',
#  'lacE',
#  'INV, sacA',
#  'E2.4.1.67',
#  'MGAM',
#  'malZ',
#  'GAA',
#  'GANC',
#  'IMA, malL',
#  'SI',
#  'agaF',
#  'agaV',
#  'agaW',
#  'agaE',
#  'agaA',
#  'agaS',
#  'agaB',
#  'agaC',
#  'agaD',
#  'UGDH, ugd',
#  'USP',
#  'GLCAK',
#  'UGT',
#  'uidA, GUSB',
#  'KL',
#  'MIOX',
#  'AKR1A1, adh',
#  'gnl, RGN',
#  'GULO',
#  'GME',
#  'VTC2_5',
#  'VTC4',
#  'IMPL2',
#  'E1.1.1.122',
#  'GalDH',
#  'GLDH',
#  'GAE, cap1J',
#  'GALUR',
#  'lgaA',
#  'lgaB',
#  'lgaC',
#  'lgoD',
#  'ulaC, sgaA',
#  'ulaB, sgaB',
#  'ulaA, sgaT',
#  'ulaG',
#  'ulaD, sgaH, sgbH',
#  'ulaE, sgaU, sgbU',
#  'araD, ulaF, sgaE, sgbE',
#  'E1.6.5.4',
#  'E1.11.1.11',
#  'DHAR',
#  'E1.10.3.3',
#  'dlgD',
#  'lyxK',
#  'ALDH',
#  'ALDH7A1',
#  'ALDH9A1',
#  'gudD',
#  'garL',
#  'ARA2',
#  'ARA1',
#  'ALO',
#  'araDH',
#  'araD',
#  'kdaD, xacE, kdxD',
#  'araA',
#  'araDH',
#  'araB',
#  'xacC',
#  'araC',
#  'araD',
#  'lxyD',
#  'aldH',
#  'dopDH',
#  'kdgD',
#  'garD',
#  'talrD-galrD',
#  'udh',
#  'gli',
#  'gci',
#  'scrA, sacP, sacX, ptsS',
#  'INV, sacA',
#  'E2.4.1.14',
#  'SPP',
#  'SUS',
#  'MGAM',
#  'malZ',
#  'GAA',
#  'GANC',
#  'SI',
#  'inuJ',
#  'sacB',
#  'lf2',
#  'sacC, levB',
#  'E2.4.1.4',
#  'E2.4.1.5',
#  'E2.4.1.7',
#  'UGP2, galU, galF',
#  'ENPP1_3, CD203',
#  'E2.4.1.34',
#  'EGLC',
#  'GN1_2_3',
#  'GN4',
#  'GN5_6',
#  'E3.2.1.58',
#  'E3.2.1.21',
#  'bglX',
#  'bglB',
#  'bcsA',
#  'E3.2.1.4',
#  'CELB',
#  'CBH1',
#  'CBH2, cbhA',
#  'E2.4.1.20',
#  'celC, chbA',
#  'celA, chbB',
#  'celB, chbC',
#  'E3.2.1.86A, celF',
#  'E3.2.1.86B, bglA',
#  'rfbF',
#  'glgC',
#  'NUDX14',
#  'glgA',
#  'WAXY',
#  'glgA',
#  'GYS',
#  'GYG1, GYG2',
#  'K16150',
#  'K16153',
#  'GBE1, glgB',
#  'K16149',
#  'PYG, glgP',
#  'AGL',
#  'glgX',
#  'pulA',
#  'AMY, amyA, malS',
#  'E3.2.1.1A',
#  'treS',
#  'E3.2.1.2',
#  'amyM',
#  'cd, ma, nplT',
#  'SGA1',
#  'susB',
#  'IMA, malL',
#  'dexA',
#  'malQ',
#  'jgt',
#  'pep2',
#  'glgE',
#  'glgM',
#  'mapA',
#  'pgmB',
#  'crr',
#  'malX',
#  'malT',
#  'glvC, malP, aglA',
#  'mapP',
#  'glvA',
#  'cgt',
#  'ISA, treX',
#  'treY, glgY',
#  'treZ, glgZ',
#  'treT',
#  'otsA',
#  'otsB',
#  'TPS',
#  'TSL1, TPS3',
#  'TREH, treA, treF',
#  'E3.2.1.28',
#  'treP',
#  'treB, treP',
#  'treC',
#  'pgm',
#  'pmm-pgm',
#  'PGM2',
#  'HK',
#  'GCK',
#  'glk',
#  'glk',
#  'G6PC',
#  'PGM2L1',
#  'GPI, pgi',
#  'pgi1',
#  'tal-pgi',
#  'pgi-pmi',
#  'E2.7.1.4, scrK',
#  'E3.2.1.14',
#  'CHIB',
#  'chiA',
#  'nagZ',
#  'HEXA_B',
#  'chbP',
#  'E3.5.1.41',
#  'csn',
#  'csxA',
#  'crr',
#  'nagE',
#  'NAGK, nagK',
#  'nagA, AMDHD2',
#  'nagB, GNPDA',
#  'gamP',
#  'HK',
#  'gspK',
#  'E2.7.1.4, scrK',
#  'glmS, GFPT',
#  'GNPNAT1, GNA1',
#  'PGM3',
#  'glmM',
#  'GALK2',
#  'glmU',
#  'glmU',
#  'UAP1',
#  'K23144',
#  'murP',
#  'murQ',
#  'anmK',
#  'mupP',
#  'amgK',
#  'murU',
#  'murA',
#  'murB',
#  'GNE',
#  'siaA, neuC1',
#  'nanK',
#  'nanEK',
#  'RENBP',
#  'nanE',
#  'NANS, SAS',
#  'NANP',
#  'neuB, nnaB',
#  'E4.1.3.3, nanA, NPL',
#  'CMAS',
#  'neuA, nnaC',
#  'CMAH',
#  'E1.6.2.2',
#  'CHS1',
#  'wecB',
#  'wecC',
#  'wbpA',
#  'tviB, vipA',
#  'wbpB',
#  'wlbA, bplA',
#  'wbpE, wlbC',
#  'wbpD, wlbB',
#  'wbpI, wlbD',
#  'wbpP',
#  'wbpO',
#  'tviC, vipB',
#  'pseB, wbjB',
#  'pseC',
#  'pseH',
#  'pseG',
#  'pseI, neuB3',
#  'pseF',
#  'pglF',
#  'pglE',
#  'pglD',
#  'legG, neuC2',
#  'legI, neuB2',
#  'legF, ptmB',
#  'E2.5.1.132',
#  'E3.1.3.103',
#  'E2.7.7.92',
#  'E2.7.1.46',
#  'USP',
#  'RGP, UTM',
#  'abfA',
#  'xynD',
#  'abf1',
#  'GLCAK',
#  'arnA, pmrI',
#  'arnB, pmrH',
#  'arnC, pmrF',
#  'arnD',
#  'UXS1, uxs',
#  'AXS',
#  'E2.4.2.24',
#  'XYL4',
#  'xynB',
#  'xylA',
#  'UXE, uxe',
#  'ptsG',
#  'malX',
#  'ptsG, glcA, glcB',
#  'glk',
#  'glk',
#  'GCK',
#  'ppgK',
#  'pgm',
#  'pmm-pgm',
#  'PGM2',
#  'UGP2, galU, galF',
#  'RHM',
#  'UER1',
#  'UGDH, ugd',
#  'SQD1, sqdB',
#  'galK',
#  'galT, GALT',
#  'galE, GALE',
#  'glf',
#  'capD',
#  'GAE, cap1J',
#  'GALAK',
#  'GAUT',
#  'manXa',
#  'manX',
#  'manY',
#  'manZ',
#  'GPI, pgi',
#  'pgi1',
#  'tal-pgi',
#  'pgi-pmi',
#  'manA, MPI',
#  'PMM',
#  'manB',
#  'K16881',
#  'GMPP',
#  'manC, cpsB',
#  'algA, xanB, rfbA, wbpW, pslB',
#  'gmd, GMDS',
#  'rmd',
#  'tld',
#  'per, rfbE',
#  'perB, wbdR',
#  'TSTA3, fcl',
#  'GME',
#  'algD',
#  'FUK',
#  'FPGT',
#  'FKGP, fkp',
#  'AFKP80',
#  'rfbF',
#  'rfbG',
#  'ascC, ddhC, rfbH',
#  'ascD, ddhD, rfbI',
#  'rfbS',
#  'rfbE',
#  'rfbJ',
#  'rfbJ',
#  'ascE',
#  'ascF',
#  'glgC',
#  'ACSS1_2, acs',
#  'AAE7, ACN1',
#  'porA',
#  'porB',
#  'porC, porG',
#  'vorG, porG',
#  'porD',
#  'por, nifJ',
#  'korA, oorA, oforA',
#  'korB, oorB, oforB',
#  'aceE',
#  'PDHA, pdhA',
#  'PDHB, pdhB',
#  'DLAT, aceF, pdhC',
#  'DLD, lpd, pdhD',
#  'PDHX',
#  'E2.3.1.54, pflD',
#  'E1.2.1.10',
#  'adhE',
#  'mhpF',
#  'bphJ, xylQ, nahO, tesF',
#  'eutE',
#  'ADH1_7',
#  'ADH4',
#  'ADH6',
#  'adhP',
#  'yiaY',
#  'E1.1.1.1, adh',
#  'frmA, ADH5, adhC',
#  'ADH1',
#  'AKR1A1, adh',
#  'ahr',
#  'yahK',
#  'mdh1, mxaF',
#  'mdh2, mxaI',
#  'exaA',
#  'eutG',
#  'adhA',
#  'adhB',
#  'ackA',
#  'E2.3.1.8, pta',
#  'pta',
#  'K15024',
#  'eutD',
#  'PK, pyk',
#  'PKLR',
#  'ACACA',
#  'ACACB',
#  'accA',
#  'accB, bccP',
#  'accC',
#  'accD',
#  'bccA, pccA',
#  'accD6',
#  'acyP',
#  'ALDH',
#  'ALDH7A1',
#  'ALDH9A1',
#  'aldB',
#  'E3.1.2.1, ACH1',
#  'aarC, cat1',
#  'pct',
#  'acdA',
#  'acdB',
#  'acdAB',
#  'E1.2.3.3, poxL',
#  'lldD',
#  'LDH, ldh',
#  'poxB',
#  'E1.13.12.4',
#  'ldhA',
#  'dld',
#  'dld',
#  'LDHD, dld',
#  'dld',
#  'DLD3',
#  'GRE2',
#  'yvgN',
#  'aldA',
#  'E1.2.1.22',
#  'GLO1, gloA',
#  'gloB, gloC, HAGH',
#  'hchA',
#  'DJ1D',
#  'GLX3, HSP31',
#  'larA',
#  'GRHPR',
#  'ghrA',
#  'ghrB',
#  'ME2, sfcA, maeA',
#  'E1.1.1.39',
#  'E1.1.1.40, maeB',
#  'oadA',
#  'madB, oadB, gcdB, mmdB',
#  'oadG',
#  'bcpA',
#  'PC, pyc',
#  'pycA',
#  'pycB',
#  'MDH1',
#  'MDH2',
#  'mdh',
#  'E1.1.1.82',
#  'mqo',
#  'E4.2.1.2A, fumA, fumB',
#  'E4.2.1.2AA, fumA',
#  'E4.2.1.2AB, fumB',
#  'E4.2.1.2B, fumC, FH',
#  'fumD',
#  'fumE',
#  'frdA',
#  'frdB',
#  'frdC',
#  'frdD',
#  'mleA, mleS',
#  'ppc',
#  'E4.1.1.32, pckA, PCK',
#  'PEPCK',
#  'E4.1.1.49, pckA',
#  'ppdK',
#  'pps, ppsA',
#  'aceB, glcB',
#  'ACAT, atoB',
#  'leuA, IMS',
#  'LYS21, LYS20',
#  'nifV',
#  'aksA',
#  'E4.1.3.1, aceA',
#  'ACSS1_2, acs',
#  'AAE7, ACN1',
#  'aceB, glcB',
#  'MDH1',
#  'MDH2',
#  'mdh',
#  'CS, gltA',
#  'ACO, acnA',
#  'acnB',
#  'mtkB',
#  'mtkA',
#  'ACAT, atoB',
#  'phbB',
#  'croR',
#  ...]

# %%
total_gene_final = [] # total genes in KEGG pathway
for gene in total_gene:
    for element in gene.split(', '):
        total_gene_final.append(element)

# %%
ind = 0

for gene in list(set(total_gene_final)):
    if gene.upper() in ppi_g.nodes:
        ind += 1

# %%
print("The number of total genes in KEGG network : " + str(len(list(set(total_gene_final)))))
# Out:
# The number of total genes in KEGG network : 20629

# %%
print("The number of genes that exist both in CODA & KEGG : " + str(ind) + ' / ' + str(len(ppi_g.nodes)))
# Out:
# The number of genes that exist both in CODA & KEGG : 7452 / 22488

# %% [markdown]
# How many CODA interactions exist that are in KEGG pathway?

# %%
for gene in list(set(total_gene_final))[:20]:
    print(gene.upper())
# Out:
# QOXB
# RNF110
# BMOX
# PATJ
# MAP7D1
# HIF1
# MALT
# IPMK
# GGUB
# SPT4
# CHMT
# E3.2.1.59
# BMYC
# FOLD
# STZF
# MAPKBP1
# PTK2
# SUN3
# ZBTB26
# NARJ
